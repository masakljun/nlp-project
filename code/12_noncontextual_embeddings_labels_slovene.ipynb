# %% [markdown]
# # Noncontextual embeddings
#
# Notebook for Word2Vec Slovene language.

# %%
import gensim
import gensim.downloader
from sklearn.manifold import TSNE
from sklearn.manifold import MDS
from sklearn.decomposition import PCA
import numpy as np
import tempfile
import imageio
import shutil
import os
from statistics import mean
import pandas as pd 
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer 
from gensim.test.utils import datapath
from gensim.models.fasttext import load_facebook_vectors

from IPython.display import Image
from IPython.display import display
pd.options.display.max_columns = None

import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

# %%
import nltk

# %%
TOP_N = 10
KEYS = { \
    "seksizem": set(), 
    "rasizem": set(), 
    "blatenje": set(), 
    "homofobija": set(), 
    #"sovražni_govor": set(), 
    "nadlegovanje": set(), 
    "žaljenje": set(), 
    "sovražnost": set(), 
    "vulgarnost": set(), 
    "bogokleten": set(), 
    "nespodoben": set(), 
    "nasilje": set(), 
    "benevolenten": set(), 
    "diskreditiranje": set(), 
    "napadalen": set(),
    "sovražen": set(),
    "grožnja": set(),
    "toksičen": set(),
    "vsiljen": set(),
    #"spletno nasilje": set(),        
}

FIXED_KEYS = list(KEYS.keys())

# %%
import lemmagen.lemmatizer
from lemmagen.lemmatizer import Lemmatizer

lemmatizer = Lemmatizer(dictionary=lemmagen.DICTIONARY_SLOVENE)

from slovene_stemmer import stem

# %%
#lemmatizer = WordNetLemmatizer() 
#ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    #stem = ps.stem(key)
    st = stem([key])
    print(st)
    KEYS[key].add(lemma)
    KEYS[key].add(st[0])
    KEYS[key].add(key)
KEYS
# Out:
# ['seksiz']
# ['rasiz']
# ['blaten']
# ['homofob']
# ['nadleg']
# ['žaljen']
# ['sovraž']
# ['vulgar']
# ['bogoklet']
# ['nespodob']
# ['nasil']
# ['benev']
# ['diskredit']
# ['napad']
# ['sovraž']
# ['grožn']
# ['toksič']
# ['vsilj']
# {'seksizem': {'seksiz', 'seksizem'},
#  'rasizem': {'rasiz', 'rasizem'},
#  'blatenje': {'blaten', 'blatenje'},
#  'homofobija': {'homofob', 'homofobija'},
#  'nadlegovanje': {'nadleg', 'nadlegovanje'},
#  'žaljenje': {'žaljen', 'žaljenje'},
#  'sovražnost': {'sovraž', 'sovražnost'},
#  'vulgarnost': {'vulgar', 'vulgarnost'},
#  'bogokleten': {'bogoklet', 'bogokleten'},
#  'nespodoben': {'nespodob', 'nespodoben'},
#  'nasilje': {'nasil', 'nasilje'},
#  'benevolenten': {'benev', 'benevolenten'},
#  'diskreditiranje': {'diskredit', 'diskreditiranje'},
#  'napadalen': {'napad', 'napadalen'},
#  'sovražen': {'sovraž', 'sovražen'},
#  'grožnja': {'grožn', 'grožnja'},
#  'toksičen': {'toksič', 'toksičen'},
#  'vsiljen': {'vsiliti', 'vsilj', 'vsiljen'}}

# %%
def same_word(similar_word, ommit_words):
    similar_word = similar_word.replace("_", " ").replace("-", " ").lower()
    
    if similar_word in ommit_words:
        print(f"{ommit_words} -- {similar_word}")
        return True
    
    for ommit_word in ommit_words:
        if ommit_word in similar_word:
            print(f"{ommit_words} -- {similar_word}")
            return True
        
    return False

# %%
def getSimilarWords(model_gn):
    embedding_clusters = []
    word_clusters = []
    for key in FIXED_KEYS:
        ommit_words = KEYS[key]
        embeddings = []
        words = []
        for similar_word, _ in model_gn.most_similar(key, topn=TOP_N * 3):
            if not same_word(similar_word, ommit_words):
                words.append(similar_word)
                embeddings.append(model_gn[similar_word])
                
        if len(words) < TOP_N or len(embeddings) < TOP_N:
            print("ERROR")
            
        words = words[:TOP_N]
        embeddings = embeddings[:TOP_N]
        
        embedding_clusters.append(embeddings)
        word_clusters.append(words)
        
    return (word_clusters, embedding_clusters)

# %%
def displayDF(word_clusters):
    df = pd.DataFrame(dict(zip(FIXED_KEYS, word_clusters)))  
    display(df)

# %%
def plot_similar_words(title, labels, embedding_clusters, word_clusters, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=0.7, label=label)
        for i, word in enumerate(words):              
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=8)
        plt.annotate(label.upper(), alpha=1.0, xy=(mean(x), mean(y)), xytext=(0, 0),
            textcoords='offset points', ha='center', va='center', size=15)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(False)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
def plotTSNE(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotMDS(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = MDS(n_components=2, max_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotPCA(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = PCA(n_components=2, random_state = 32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plot_similar_words3d(title, labels, embedding_clusters, word_clusters, filename=None):
    fig = plt.figure(figsize=(16, 9))
    ax = fig.add_subplot(projection='3d')
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        z = embeddings[:, 2]
        ax.scatter(x, y,z, c=color, alpha=0.7, label=label)
        #for i, word in enumerate(words):              
            #plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
            #             textcoords='offset points', ha='right', va='bottom', size=8)
        #    plt.text(x,y,z, word, alpha=0.5,
        #                 textcoords='offset points', ha='right', va='bottom', size=8)
        #    ax.text(x,y,z, word, alpha=1.0,
        #        textcoords='offset points', ha='center', va='center', size=15)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(False)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
def plotMDS3D(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_3d = MDS(n_components=3, max_iter=3500, random_state=32)
    model_en_3d = model_en_3d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_3d = np.array(model_en_3d).reshape(n, m, 3)
    plot_similar_words3d(title, FIXED_KEYS, embeddings_en_3d, word_clusters, filename)

# %%
#model_gn = gensim.downloader.load('word2vec-google-news-300')
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
model = KeyedVectors.load_word2vec_format("models/model.bin", binary = True)

# %%
word_clusters_a, embedding_clusters = getSimilarWords(model)
# Out:
# {'seksizem', 'seksiz'} -- seksizma
# {'homofob', 'homofobija'} -- homofobijo
# {'nadlegovanje', 'nadleg'} -- nadlegovanja
# {'sovraž', 'sovražnost'} -- sovražnosti
# {'nasil', 'nasilje'} -- nasilja
# {'nasil', 'nasilje'} -- nasiljem
# {'nasil', 'nasilje'} -- nasilju
# {'nasil', 'nasilje'} -- nasilno
# {'sovraž', 'sovražen'} -- sovražni
# {'grožn', 'grožnja'} -- grožnje
# {'grožn', 'grožnja'} -- grožnjo
# {'toksič', 'toksičen'} -- nevrotoksičen
# {'toksič', 'toksičen'} -- genotoksičen

# %%
displayDF(word_clusters_a)
# Out:
#         seksizem          rasizem      blatenje       homofobija  \
# 0   benevolenten  partnerjazenske       žalitev      ksenofobija
# 1      šovinizem  partnerjastrani      žaljenje         seksizem
# 2      mazohizem      ksenofobija     zmerjanje         seksizma
# 3    ksenofobija  homoseksualnost   licemerstvo   homoseksualcev
# 4      feminizem        terorizem     navzdolne        feminizem
# 5     homofobija        šovinizem  kritiziranje        šovinizem
# 6   antisocialno      narkomanija  natolcevanje  homoseksualnost
# 7    nekrofilija     konsenzualne    norčevanje        muslimank
# 8  socializirano       neonacizem       krsenje           kuffar
# 9        nasilje       pedofilija  demonizacijo          sadizem
#
#      nadlegovanje      žaljenje     sovražnost     vulgarnost bogokleten  \
# 0         nasilje  kritiziranje    sumničavost   samovšečnost     glumil
# 1     šikaniranje      zaljenje     nezaupanje  prevarantstvo      nutku
# 2    ustrahovanje  zasmehovanje  brezobzirnost      otroškost    upognil
# 3       posilstvo      blatenje      sovraštvo      banalnost       blio
# 4      trpinčenje     zmerjanje  prepirljivost  kategoričnega    bavbav.
# 5     poniževanje  primitivnost  zagrenjenosti     tragičnost  trdosrčen
# 6  diskriminacijo   poniževanje    napadalnost       smešnost  žalostila
# 7       nemoralno     žaljivega     brezupnost   nihilistična  pokeraško
# 8      pretepanje       žalitev  prestopništvo     ranjenosti      gabil
# 9         kaznivo   namigovanje    agresivnost  škodoželjnost     stvoru
#
#         nespodoben            nasilje    benevolenten diskreditiranje  \
# 0       sadističen       nadlegovanje      odrešujoče  administrirajo
# 1         neiskren       medvrstniško   socializirano      asocialnih
# 2        zajedljiv          posilstvo      ateističen     servilnosti
# 3         postaran  intimnopartnersko        vživetje         nacizme
# 4  nacionalističen             delikt  protikrščansko      sramotitev
# 5       nedružaben         homofobijo        atavizem       anarhične
# 6     gospodovalen          sovraštvo  razčlovečenost         sre~nih
# 7       domoljuben        poniževanje       teistično   perpetuiranje
# 8       sugestiven     stigmatizacije       'tveganje        cincanje
# 9          spraven         nestrpnost          zamolk      _dejansko_
#
#     napadalen      sovražen          grožnja      toksičen            vsiljen
# 0     nasilen  polovičarski  izkoriščevalska    karcinogen           podivjal
# 1      plašen     ponižujoč        naperjena     nukleofil          dejanjski
# 2  nespodoben   nespoštljiv        nevarnost       strupen    sužnjelastniški
# 3   zlovoljen  razčlovečiti         uperjena           uf6       destruktiven
# 4        plah  stigmatizira       sprevržena      fosforju  kontraproduktiven
# 5   vzkipljiv       udbaški       nespametna     bromelain              izzum
# 6   agresiven      vulgaren        neizbežna      katalaza       korporatizem
# 7   svojeglav        žaljiv          pretila         topen      človekoljuben
# 8  sadističen    nedostojen            gonja  diklorometan           hribovec
# 9   posesiven      nravnemu          pomisel     prekurzor           neetičen

# %%
plotMDS3D("Similar words - Word2Vec [MDS]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - MDS_3d.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-bf41568ee010> in <module>
# ----> 1 plotMDS3D("Similar words - Word2Vec [MDS]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - MDS_3d.png")
#
# NameError: name 'plotMDS3D' is not defined

# %%
plotTSNE("Word2Vec embeddings - t-SNE visualization", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - t-SNE_1.png")

# %%
plotMDS("Similar words - Word2Vec [MDS]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - MDS_1.png")

# %%
plotPCA("Similar words - Word2Vec [PCA]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - PCA_1.png")

# %% [markdown]
# ## Clustering

# %% [markdown]
# Compute average vectors from the embedding words

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %% [markdown]
# ### KMean

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

range_clusters = list(range(2,10))
avg = []
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    avg.append(silhouette_avg)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")
# Out:
# 2 clusters - silhouette: 0.6062533855438232
# 3 clusters - silhouette: 0.32397884130477905
# 4 clusters - silhouette: 0.30158963799476624
# 5 clusters - silhouette: 0.3037530183792114
# 6 clusters - silhouette: 0.30856630206108093
# 7 clusters - silhouette: 0.3169940710067749
# 8 clusters - silhouette: 0.26345640420913696
# 9 clusters - silhouette: 0.254637748003006

# %%
plt.figure(figsize=(7, 2.8))
plt.plot(range_clusters, avg)
plt.title("Silhouette score - k-means clustering")
plt.xlabel("k")
plt.ylabel("silhouette score")
# Out:
# Text(0, 0.5, 'silhouette score')

# %%
num_clusters = 7
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
# Out:
# Wall time: 77.5 ms
# Clusters: [0, 0, 5, 0, 6, 5, 0, 1, 3, 3, 0, 1, 1, 3, 1, 4, 2, 3]

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")
# Out:
# Cluster 0: ['seksizem' 'rasizem' 'homofobija' 'sovražnost' 'nasilje']
# Cluster 1: ['vulgarnost' 'benevolenten' 'diskreditiranje' 'sovražen']
# Cluster 2: ['toksičen']
# Cluster 3: ['bogokleten' 'nespodoben' 'napadalen' 'vsiljen']
# Cluster 4: ['grožnja']
# Cluster 5: ['blatenje' 'žaljenje']
# Cluster 6: ['nadlegovanje']

# %% [markdown]
# ### Hierarhical clustering

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()

# %% [markdown]
# # glove

# %%
# stran dala: douchebag, feminazi

# %%
TOP_N = 30
KEYS = { \
    "offensive": set(), 
    "abusive": set(), 
    "cyberbullying": set(), 
    "vulgar": set(), 
    "racist": set(), 
    "homophobic": set(), 
    "profane": set(), 
    "slur": set(), 
    "harrasment": set(), 
    "obscene": set(), 
    "threat": set(), 
    "discredit": set(), 
    "hateful": set(), 
    "insult": set(), 
    "hostile": set(),
    "sexism": set(),
    "spam": set(),
    "benevolent": set(),
    "toxic": set(),        
}
FIXED_KEYS = list(KEYS.keys())

lemmatizer = WordNetLemmatizer() 
ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    stem = ps.stem(key)
    KEYS[key].add(lemma)
    KEYS[key].add(stem)
    KEYS[key].add(key)
KEYS
# Out:
# {'offensive': {'offens', 'offensive'},
#  'abusive': {'abus', 'abusive'},
#  'cyberbullying': {'cyberbulli', 'cyberbullying'},
#  'vulgar': {'vulgar'},
#  'racist': {'racist'},
#  'homophobic': {'homophob', 'homophobic'},
#  'profane': {'profan', 'profane'},
#  'slur': {'slur'},
#  'harrasment': {'harras', 'harrasment'},
#  'obscene': {'obscen', 'obscene'},
#  'threat': {'threat'},
#  'discredit': {'discredit'},
#  'hateful': {'hate', 'hateful'},
#  'insult': {'insult'},
#  'hostile': {'hostil', 'hostile'},
#  'sexism': {'sexism'},
#  'spam': {'spam'},
#  'benevolent': {'benevol', 'benevolent'},
#  'toxic': {'toxic'}}

# %%
model_gn = gensim.downloader.load('glove-wiki-gigaword-300')

# %%
word_clusters, embedding_clusters = getSimilarWords(model_gn)
# Out:
# {'offens', 'offensive'} -- offense
# {'offens', 'offensive'} -- offensives
# {'offens', 'offensive'} -- offensively
# {'abus', 'abusive'} -- abuse
# {'abus', 'abusive'} -- abused
# {'abus', 'abusive'} -- abusing
# {'vulgar'} -- vulgarity
# {'racist'} -- racists
# {'homophobic', 'homophob'} -- homophobia
# {'profan', 'profane'} -- profanity
# {'slur'} -- slurs
# {'harrasment', 'harras'} -- harrassment
# {'obscen', 'obscene'} -- obscenity
# {'obscen', 'obscene'} -- obscenities
# {'threat'} -- threats
# {'threat'} -- threatening
# {'threat'} -- threatened
# {'threat'} -- threaten
# {'threat'} -- threatens
# {'discredit'} -- discrediting
# {'discredit'} -- discredited
# {'hate', 'hateful'} -- hate
# {'insult'} -- insulting
# {'insult'} -- insults
# {'insult'} -- insulted
# {'hostile', 'hostil'} -- hostility
# {'sexism'} -- heterosexism
# {'spam'} -- spammers
# {'spam'} -- spamming
# {'spam'} -- spammer
# {'spam'} -- anti spam
# {'benevolent', 'benevol'} -- benevolence
# {'toxic'} -- toxicity

# %%
displayDF(word_clusters)
# Out:
#         offensive         abusive      cyberbullying         vulgar  \
# 0       defensive      neglectful           bullying        profane
# 1         lineman   inappropriate      cyberstalking        obscene
# 2         linemen        sexually     cyber-bullying        raunchy
# 3     coordinator      stepfather            sexting         risque
# 4          attack        behavior           anti-gay          crass
# 5     quarterback        verbally        vigilantism         sexist
# 6           blitz     overbearing      victimisation      tasteless
# 7          forces        bullying      victimization     suggestive
# 8        fighting   disrespectful          self-harm     derogatory
# 9          tackle     domineering        harrassment  disrespectful
# 10      attacking        husbands  institutionalised           rude
# 11        assault  discriminatory            falkoff          slang
# 12       patriots    exploitative        anti-muslim      demeaning
# 13   quarterbacks       alcoholic          autistics      profanity
# 14       defenses       practices        self-injury     disgusting
# 15      onslaught       behaviour          anti-spam           racy
# 16        attacks    manipulative      nanostructure          bawdy
# 17        raiders      oppressive         cybercrime       impolite
# 18         troops         immoral      anti-bullying   misogynistic
# 19      backfield         corrupt            texting   scatological
# 20  counterattack        coercive     licentiousness          jokes
# 21         rebels         priests             rasted  inappropriate
# 22         effort          racist            ragging     homophobic
# 23            nfl       insulting         homophobic           lewd
# 24           jets        improper        revisionary    pretentious
# 25          raids    unscrupulous           spamming        hateful
# 26           army         violent      exhibitionism     irreverent
# 27          rebel   irresponsible           galiardi      obnoxious
# 28      firepower       demeaning       islamophobia    insensitive
# 29       starting       deceptive            bullies     outrageous
#
#             racist     homophobic        profane          slur  \
# 0       homophobic         sexist         vulgar    derogatory
# 1           sexist         racist        raunchy    homophobic
# 2          semitic   misogynistic        obscene      epithets
# 3       xenophobic          slurs      vulgarity   disparaging
# 4     anti-semitic     misogynist   misogynistic       uttered
# 5      antisemitic        bigoted         ribald        racist
# 6            slurs    antisemitic     irreverent        nigger
# 7           racism   anti-semitic   scatological       epithet
# 8          hateful     xenophobic           rude        sexist
# 9          bigoted        semitic          bawdy       semitic
# 10            hate           slur  disrespectful  stereotyping
# 11          racial        hateful         risque        remark
# 12        racially       anti-gay      demeaning   obscenities
# 13            slur       bullying     derogatory   profanities
# 14  discriminatory    disparaging      sarcastic        racial
# 15      derogatory  disrespectful         sexist        insult
# 16       insulting       epithets       impolite    pejorative
# 17         fascist     intolerant    hilariously      uttering
# 18         insults     derogatory         tirade        vulgar
# 19          taunts    insensitive        hateful        tirade
# 20    misogynistic  condescending        playful    expletives
# 21        epithets         vulgar     suggestive   insensitive
# 22         violent        bigotry       epithets     demeaning
# 23     stereotypes    transphobic      outbursts       insults
# 24      misogynist   chauvinistic      obnoxious       bigoted
# 25   disrespectful       misogyny        boorish    defamatory
# 26          hatred     prejudiced     homophobic     insulting
# 27      denouncing   hypocritical     expletives     profiling
# 28     disparaging      demeaning          rants  scapegoating
# 29     insensitive         taunts           lewd        taunts
#
#                                  harrasment        obscene        threat  \
# 0                                    romish       indecent        danger
# 1                                      pi96           lewd         posed
# 2                               nonfeasance         vulgar          pose
# 3                                      zety        profane   possibility
# 4                          depressurisation   pornographic        warned
# 5                                  keyrates  inappropriate       warning
# 6                                   jiwamol      insulting         poses
# 7                            demoralisation     defamatory      imminent
# 8                                supunnabul       gestures       dangers
# 9                              ryryryryryry        immoral      possible
# 10                                     rw96  objectionable     terrorism
# 11                             equidistance     derogatory       concern
# 12                                kanoksilp    pornography     potential
# 13                                continous    blasphemous     terrorist
# 14                            _____________  disrespectful         fears
# 15                               suwannakij        gesture         risks
# 16                     tom.fowler@chron.com   sacrilegious       serious
# 17                                zilliacus     subversive      concerns
# 18                                     rw97         deemed          risk
# 19                            rungfapaisarn       libelous      warnings
# 20                                   ufdots     outrageous          fear
# 21                              mongkolporn         racist  consequences
# 22                                rosnazura        hateful       attacks
# 23                                     cw96      demeaning           any
# 24                             compulsivity       explicit        terror
# 25  ooooooooooooooooooooooooooooooooooooooo     suggestive        facing
# 26                                aldingham     lascivious         alert
# 27                               westendorf    disparaging       looming
# 28                              misfeasance       unlawful          warn
# 29                                     mo96      seditious     concerned
#
#          discredit        hateful         insult          hostile  \
# 0        undermine        bigoted        affront       unfriendly
# 1        embarrass        hurtful     disrespect         takeover
# 2       intimidate         racist         offend      belligerent
# 3           defame           vile    humiliation     antagonistic
# 4            rebut     homophobic          shame            enemy
# 5        humiliate         sexist    provocation        takeovers
# 6          tarnish     despicable       ridicule          threats
# 7            smear     intolerant  embarrassment       aggressive
# 8      destabilize        idiotic  disrespectful             fend
# 9          portray     disgusting      injustice          enemies
# 10     marginalize       ignorant           slur           thwart
# 11          accuse       spiteful     outrageous       intentions
# 12         subvert      vitriolic        slander         friendly
# 13          refute      bellicose       offended     increasingly
# 14       denigrate        semitic      indignity              bid
# 15        demonize     xenophobic        dignity      threatening
# 16         mislead  disrespectful      humiliate         engaging
# 17  disinformation        profane        mockery          actions
# 18     destabilise   anti-semitic     compliment          violent
# 19            ploy    intemperate      apologize        overtures
# 20     undermining         vulgar       disgrace          abusive
# 21      accusation   misogynistic         racist           engage
# 22        undercut      demeaning      demeaning         attempts
# 23        distract       barbaric      perceived         opposing
# 24          depose      murderous           joke  confrontational
# 25    orchestrated       shameful        mocking           threat
# 26         deflect         hatred         remark        outsiders
# 27          vilify   contemptuous     gratuitous           stance
# 28        disprove   bloodthirsty         sexist       suspicious
# 29     assassinate     vindictive   exaggeration         attitude
#
#             sexism           spam       benevolent          toxic
# 0       homophobia         e-mail        patrolmen      poisonous
# 1           racism      filtering       malevolent      chemicals
# 2         misogyny       phishing       omnipotent         toxins
# 3           ageism          email        fraternal    radioactive
# 4          bigotry        spyware       beneficent      hazardous
# 5    anti-semitism        senders      domineering   contaminants
# 6          elitism         emails    paternalistic     pesticides
# 7         classism          mails       villainous          waste
# 8     stereotyping           junk          saintly   contaminated
# 9     antisemitism          faxes       tyrannical         wastes
# 10       prejudice    unsolicited            deity        harmful
# 11        feminism              e  personification         sludge
# 12      lesbianism         sender           kindly     pollutants
# 13          sexist           mail             elks       chemical
# 14        semitism         filter      enlightened          fumes
# 15      xenophobia        malware           genial  contamination
# 16           overt        filters        heartless     substances
# 17     intolerance       messages            pious   carcinogenic
# 18      patriarchy  telemarketing         despotic        noxious
# 19     stereotypes        e-mails         merciful         dioxin
# 20      chauvinism        mailing           loving        arsenic
# 21       hypocrisy       internet     wisecracking       polluted
# 22      oppression    pornography    compassionate      pesticide
# 23  discrimination         usenet         vengeful      pollution
# 24   condescension       filtered      overbearing      corrosive
# 25     criminality        mailers          zealous       asbestos
# 26          biases      messaging          angelic        dioxins
# 27    internalized         delete     antagonistic      compounds
# 28     colonialism        viruses             evil       chlorine
# 29      prejudices        servers          haughty      flammable

# %%
plotTSNE("GloVe embeddings - t-SNE visualization", word_clusters, embedding_clusters, "SimilarWords - Glove - t-SNE_1.png")

# %%
plotMDS("Similar words - Glove [MDS]", word_clusters, embedding_clusters, "SimilarWords - Glove - MDS_1.png")

# %%
plotPCA("Similar words - Glove [PCA]", word_clusters, embedding_clusters, "SimilarWords - Glove - PCA_1.png")

# %% [markdown]
# ## Clustering

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %% [markdown]
# ### KMeans

# %%
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))
range_clusters = list(range(2,10))
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")
# Out:
# 2 clusters - silhouette: 0.43420594930648804
# 3 clusters - silhouette: 0.38454189896583557
# 4 clusters - silhouette: 0.34826821088790894
# 5 clusters - silhouette: 0.34746015071868896
# 6 clusters - silhouette: 0.3578161895275116
# 7 clusters - silhouette: 0.34181633591651917
# 8 clusters - silhouette: 0.3196745812892914
# 9 clusters - silhouette: 0.30135390162467957

# %%
num_clusters = 6
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
# Out:
# Wall time: 32.4 ms
# Clusters: [4, 1, 0, 1, 1, 1, 1, 1, 5, 1, 4, 2, 1, 1, 2, 0, 3, 0, 3]

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")
# Out:
# Cluster 0: ['cyberbullying' 'sexism' 'benevolent']
# Cluster 1: ['abusive' 'vulgar' 'racist' 'homophobic' 'profane' 'slur' 'obscene'
#  'hateful' 'insult']
# Cluster 2: ['discredit' 'hostile']
# Cluster 3: ['spam' 'toxic']
# Cluster 4: ['offensive' 'threat']
# Cluster 5: ['harrasment']

# %% [markdown]
# ### Hierarchical

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()

# %% [markdown]
# # fasttext

# %%
# Run first time only to download model
#import fasttext.util
#fasttext.util.download_model('en', if_exists='ignore')  # English
#ft = fasttext.load_model('cc.en.300.bin')

# %%
model_gn = load_facebook_vectors("models/cc.sl.300.bin.gz")

# %%
TOP_N = 10
KEYS = { \
    "seksizem": set(), 
    "rasizem": set(), 
    "blatenje": set(), 
    "homofobija": set(), 
    #"sovražni_govor": set(), 
    #"nadlegovanje": set(), 
    "žaljenje": set(), 
    "sovražnost": set(), 
    "vulgarnost": set(), 
    "bogokleten": set(), 
    "nespodoben": set(), 
    "nasilje": set(), 
    "benevolenten": set(), 
    "diskreditiranje": set(), 
    "napadalen": set(),
    #"sovražen": set(),
    "grožnja": set(),
   # "toksičen": set(),
    "vsiljen": set(),
    #"spletno nasilje": set(),        
}

FIXED_KEYS = list(KEYS.keys())

# %%
import lemmagen.lemmatizer
from lemmagen.lemmatizer import Lemmatizer

lemmatizer = Lemmatizer(dictionary=lemmagen.DICTIONARY_SLOVENE)

from slovene_stemmer import stem

# %%
#lemmatizer = WordNetLemmatizer() 
#ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    #stem = ps.stem(key)
    st = stem([key])
    print(st)
    KEYS[key].add(lemma)
    KEYS[key].add(st[0])
    KEYS[key].add(key)
KEYS
# Out:
# ['seksiz']
# ['rasiz']
# ['blaten']
# ['homofob']
# ['žaljen']
# ['sovraž']
# ['vulgar']
# ['bogoklet']
# ['nespodob']
# ['nasil']
# ['benev']
# ['diskredit']
# ['napad']
# ['grožn']
# ['vsilj']
# {'seksizem': {'seksiz', 'seksizem'},
#  'rasizem': {'rasiz', 'rasizem'},
#  'blatenje': {'blaten', 'blatenje'},
#  'homofobija': {'homofob', 'homofobija'},
#  'žaljenje': {'žaljen', 'žaljenje'},
#  'sovražnost': {'sovraž', 'sovražnost'},
#  'vulgarnost': {'vulgar', 'vulgarnost'},
#  'bogokleten': {'bogoklet', 'bogokleten'},
#  'nespodoben': {'nespodob', 'nespodoben'},
#  'nasilje': {'nasil', 'nasilje'},
#  'benevolenten': {'benev', 'benevolenten'},
#  'diskreditiranje': {'diskredit', 'diskreditiranje'},
#  'napadalen': {'napad', 'napadalen'},
#  'grožnja': {'grožn', 'grožnja'},
#  'vsiljen': {'vsiliti', 'vsilj', 'vsiljen'}}

# %%
word_clusters, embedding_clusters = getSimilarWords(model_gn)
word_clusters
# Out:
# {'seksizem', 'seksiz'} -- seksizem
# {'seksizem', 'seksiz'} -- cisseksizem
# {'seksizem', 'seksiz'} -- heteroseksizem
# {'seksizem', 'seksiz'} -- seksizmu
# {'seksizem', 'seksiz'} -- heteroseksizem
# {'seksizem', 'seksiz'} -- seksizma
# {'rasizem', 'rasiz'} -- rasizem
# {'rasizem', 'rasiz'} -- rasizma
# {'rasizem', 'rasiz'} -- rasizmu
# {'blaten', 'blatenje'} -- blatenje
# {'blaten', 'blatenje'} -- blatenjem
# {'blaten', 'blatenje'} -- blatenja
# {'blaten', 'blatenje'} -- blatenju
# {'homofob', 'homofobija'} -- homofobija
# {'žaljen', 'žaljenje'} -- razžaljenje
# {'žaljen', 'žaljenje'} -- žaljenje
# {'žaljen', 'žaljenje'} -- žaljenju
# {'žaljen', 'žaljenje'} -- užaljenost
# {'žaljen', 'žaljenje'} -- žaljenja
# {'žaljen', 'žaljenje'} -- žaljeno
# {'sovraž', 'sovražnost'} -- sovražnost
# {'sovraž', 'sovražnost'} -- agresivnost sovražnost
# {'sovraž', 'sovražnost'} -- sovražnostjo
# {'sovraž', 'sovražnost'} -- agresivnost sovražnost
# {'sovraž', 'sovražnost'} -- sovražnosti
# {'sovraž', 'sovražnost'} -- sovražnostih
# {'sovraž', 'sovražnost'} -- agresivnostjo sovražnostjo
# {'sovraž', 'sovražnost'} -- agresivnosti sovražnosti
# {'sovraž', 'sovražnost'} -- sovražnostim
# {'sovraž', 'sovražnost'} -- sovražnostmi
# {'sovraž', 'sovražnost'} -- sovražnosti
# {'sovraž', 'sovražnost'} -- sovražtva
# {'vulgarnost', 'vulgar'} -- vulgarnostjo
# {'vulgarnost', 'vulgar'} -- vulgarnosti
# {'vulgarnost', 'vulgar'} -- vulgarizacija
# {'vulgarnost', 'vulgar'} -- vulgarno
# {'vulgarnost', 'vulgar'} -- vulgarna
# {'vulgarnost', 'vulgar'} -- vulgarizem
# {'bogokleten', 'bogoklet'} -- bogokletni
# {'bogokleten', 'bogoklet'} -- bogokletne
# {'bogokleten', 'bogoklet'} -- bogokletno
# {'bogokleten', 'bogoklet'} -- bogokletja
# {'bogokleten', 'bogoklet'} -- bogokletneža
# {'bogokleten', 'bogoklet'} -- bogokletju
# {'bogokleten', 'bogoklet'} -- bogokletnih
# {'bogokleten', 'bogoklet'} -- bogokletnik
# {'bogokleten', 'bogoklet'} -- bogokletje
# {'bogokleten', 'bogoklet'} -- bogokletnega
# {'nespodob', 'nespodoben'} -- nespodobni
# {'nespodob', 'nespodoben'} -- nespodobne
# {'nespodob', 'nespodoben'} -- nespodobnega
# {'nespodob', 'nespodoben'} -- nespodobno
# {'nespodob', 'nespodoben'} -- nespodobna
# {'nespodob', 'nespodoben'} -- nespodobni
# {'nespodob', 'nespodoben'} -- nespodobnost
# {'nespodob', 'nespodoben'} -- nespodobnih
# {'nespodob', 'nespodoben'} -- nespodobnimi
# {'nespodob', 'nespodoben'} -- nespodobnosti
# {'nespodob', 'nespodoben'} -- nespodobnim
# {'nasil', 'nasilje'} -- nasilje
# {'nasil', 'nasilje'} -- nasilj
# {'nasil', 'nasilje'} -- nenasilje
# {'nasil', 'nasilje'} -- nasiljem
# {'nasil', 'nasilje'} -- nenasilje
# {'nasil', 'nasilje'} -- nasilja
# {'nasil', 'nasilje'} -- nasiljem
# {'nasil', 'nasilje'} -- nasilji
# {'nasil', 'nasilje'} -- nasilja.
# {'nasil', 'nasilje'} -- nasilništvo
# {'nasil', 'nasilje'} -- nasiljatrg
# {'nasil', 'nasilje'} -- nasilneži
# {'nasil', 'nasilje'} -- nasilneže
# {'nasil', 'nasilje'} -- nasilstvo
# {'nasil', 'nasilje'} -- nasilju
# {'nasil', 'nasilje'} -- 5 2 2013 dr milko mikola n rde e nasilje
# {'nasil', 'nasilje'} -- nasiljih
# {'nasil', 'nasilje'} -- nasilj
# {'nasil', 'nasilje'} -- nasilno
# {'benev', 'benevolenten'} -- benevolenten
# {'benev', 'benevolenten'} -- benevolentno
# {'diskreditiranje', 'diskredit'} -- diskreditiranja
# {'diskreditiranje', 'diskredit'} -- diskreditirani
# {'diskreditiranje', 'diskredit'} -- diskreditirana
# {'diskreditiranje', 'diskredit'} -- diskreditiran
# {'diskreditiranje', 'diskredit'} -- diskreditacijo
# {'diskreditiranje', 'diskredit'} -- diskreditirat
# {'diskreditiranje', 'diskredit'} -- diskreditira
# {'diskreditiranje', 'diskredit'} -- diskreditirajo
# {'diskreditiranje', 'diskredit'} -- diskreditirali
# {'diskreditiranje', 'diskredit'} -- diskreditiral
# {'diskreditiranje', 'diskredit'} -- diskreditiralo
# {'diskreditiranje', 'diskredit'} -- diskreditirati
# {'diskreditiranje', 'diskredit'} -- diskreditirala
# {'diskreditiranje', 'diskredit'} -- diskreditirajoči
# {'diskreditiranje', 'diskredit'} -- diskreditacije
# {'napad', 'napadalen'} -- nenapadalen
# {'napad', 'napadalen'} -- napadalčev
# {'napad', 'napadalen'} -- napadalec
# {'napad', 'napadalen'} -- napadalc
# {'napad', 'napadalen'} -- napadalni
# {'napad', 'napadalen'} -- fw napadalec
# {'napad', 'napadalen'} -- napadale
# {'napad', 'napadalen'} -- napadalčevi
# {'napad', 'napadalen'} -- napadalke
# {'napad', 'napadalen'} -- napadalneje
# {'napad', 'napadalen'} -- napadalki
# {'napad', 'napadalen'} -- napadaš
# {'napad', 'napadalen'} -- napadalcičeški
# {'grožn', 'grožnja'} -- grožnj
# {'grožn', 'grožnja'} -- grožnjami11.
# {'grožn', 'grožnja'} -- grožnja
# {'grožn', 'grožnja'} -- grožnjami.več
# {'grožn', 'grožnja'} -- grožnje.
# {'grožn', 'grožnja'} -- grožnjam
# {'grožn', 'grožnja'} -- grožnjaokolju
# {'grožn', 'grožnja'} -- grožnjah
# {'grožn', 'grožnja'} -- grožnje
# {'grožn', 'grožnja'} -- grožnji
# {'grožn', 'grožnja'} -- grožnjo
# {'grožn', 'grožnja'} -- grožnjami
# {'grožn', 'grožnja'} -- grožno
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljen
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljeni
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenec
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljena
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljeno
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljene
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenje
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenih
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenim
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenega
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljeval
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenimi
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljeno
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenem
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljenca
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljevale
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljevalo
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljevali
# {'vsiliti', 'vsiljen', 'vsilj'} -- vsiljiv
# [['Bruksizem',
#   'Rasizem',
#   'bruksizem',
#   'fasizem',
#   'mačizem',
#   'seksualizem',
#   'Sizeizem',
#   'rasizem',
#   'krausizem',
#   'fetišizem'],
#  ['fasizem',
#   'Bruksizem',
#   'krausizem',
#   'bruksizem',
#   'seksizem',
#   'izem',
#   'Tačizem',
#   'Seksizem',
#   'snobizem',
#   'Sizeizem'],
#  ['klatenje',
#   'platenje',
#   'mlatenje',
#   'zlatenje',
#   'Ihtenje',
#   'tenje',
#   'ihtenje',
#   'Drhtenje',
#   'črtenje',
#   'Zlatenje'],
#  ['fazmofobija',
#   'dromofobija',
#   'ginofobija',
#   'Kromofobija',
#   'Bifobija',
#   'Kemofobija',
#   'lalofobija',
#   'tafofobija',
#   'zoofobija',
#   'osmofobija'],
#  ['šaljenje',
#   'žvaljenje',
#   'hvaljenje',
#   'samohvaljenje',
#   'razgaljenje',
#   'Škíljenje',
#   'mazíljenje',
#   'AWB-janje',
#   'buljenje',
#   'naalkaljenje'],
#  ['Vzdražnost',
#   'lažnost',
#   'vzdražnost',
#   'Važnost',
#   'užaljenost',
#   'žnost',
#   'moĹžnost',
#   'Vlážnost',
#   'Kúžnost',
#   'konfliktnost'],
#  ['arnost',
#   'Imúnost',
#   'političnost',
#   'bizarnost',
#   'Psévdoznánost',
#   'družbenost',
#   'zoprnost',
#   'Slánost',
#   'brezléčnost',
#   'prav-nost'],
#  ['38-leten',
#   '64-leten',
#   '21-leten',
#   '16-leten',
#   '46leten',
#   '27-leten',
#   '4-leten',
#   '26-leten',
#   '17-leten',
#   '53-leten'],
#  ['spodoben',
#   'Spodoben',
#   'Kaondolgodoben',
#   'dolgodoben',
#   'kratkodoben',
#   'dober-hudoben',
#   'novodoben',
#   'podoben',
#   'ZDASodoben',
#   'spodobni'],
#  ['zlorabljanje',
#   'Ustrahovanje',
#   'ustrahovanje',
#   'nadlegovanje',
#   'posiljevanje',
#   'Izsiljevanje',
#   'vsiljevanje',
#   'silje',
#   'izsiljevanje',
#   'zlorabljeno'],
#  ['Tenten',
#   'Dienten',
#   'amedrenten',
#   'Menten',
#   'Quenten',
#   'dipenten',
#   'sukulenten',
#   'Patienten',
#   'Liturgiedozenten',
#   'dreizehnten'],
#  ['akreditiranje',
#   'mikrokreditiranje',
#   'kreditiranje',
#   'Kreditiranje',
#   'agitiranje',
#   'bonitiranje',
#   'asisitiranje',
#   'Citiranje',
#   'samocitiranje',
#   'meditiranje'],
#  ['nadalen',
#   'Cadalen',
#   'brutalen',
#   'razdiralen',
#   'igralen',
#   'Odalen',
#   'Møysalen',
#   'Roerdalen',
#   'tekmovalen',
#   'vpadljiv'],
#  ['Požnja',
#   'voĹžnja',
#   'grožja',
#   'Mržnja',
#   '-nevarnost',
#   'ekovožnja',
#   'Jahalomin',
#   'nevarnost',
#   '2,2-13',
#   'bojazen'],
#  ['izsiljen',
#   'Giljen',
#   'Neizsiljen',
#   'posiljen',
#   'prisliljen',
#   'siljeno',
#   'siljeni',
#   'Izsiljena',
#   'opiljen',
#   'neprisiljen']]

# %%
displayDF(word_clusters)
# Out:
#       seksizem    rasizem  blatenje   homofobija       žaljenje    sovražnost  \
# 0    Bruksizem    fasizem  klatenje  fazmofobija       šaljenje    Vzdražnost
# 1      Rasizem  Bruksizem  platenje  dromofobija      žvaljenje       lažnost
# 2    bruksizem  krausizem  mlatenje   ginofobija      hvaljenje    vzdražnost
# 3      fasizem  bruksizem  zlatenje  Kromofobija  samohvaljenje       Važnost
# 4      mačizem   seksizem   Ihtenje     Bifobija    razgaljenje    užaljenost
# 5  seksualizem       izem     tenje   Kemofobija      Škíljenje         žnost
# 6     Sizeizem    Tačizem   ihtenje   lalofobija     mazíljenje      moĹžnost
# 7      rasizem   Seksizem  Drhtenje   tafofobija      AWB-janje      Vlážnost
# 8    krausizem   snobizem   črtenje    zoofobija       buljenje       Kúžnost
# 9    fetišizem   Sizeizem  Zlatenje   osmofobija   naalkaljenje  konfliktnost
#
#       vulgarnost bogokleten      nespodoben       nasilje      benevolenten  \
# 0         arnost   38-leten        spodoben  zlorabljanje            Tenten
# 1        Imúnost   64-leten        Spodoben  Ustrahovanje           Dienten
# 2    političnost   21-leten  Kaondolgodoben  ustrahovanje        amedrenten
# 3      bizarnost   16-leten      dolgodoben  nadlegovanje            Menten
# 4  Psévdoznánost    46leten     kratkodoben  posiljevanje           Quenten
# 5     družbenost   27-leten   dober-hudoben  Izsiljevanje          dipenten
# 6       zoprnost    4-leten       novodoben   vsiljevanje        sukulenten
# 7        Slánost   26-leten         podoben         silje         Patienten
# 8    brezléčnost   17-leten      ZDASodoben  izsiljevanje  Liturgiedozenten
# 9      prav-nost   53-leten        spodobni   zlorabljeno       dreizehnten
#
#      diskreditiranje   napadalen     grožnja      vsiljen
# 0      akreditiranje     nadalen      Požnja     izsiljen
# 1  mikrokreditiranje     Cadalen     voĹžnja       Giljen
# 2       kreditiranje    brutalen      grožja   Neizsiljen
# 3       Kreditiranje  razdiralen      Mržnja     posiljen
# 4         agitiranje     igralen  -nevarnost   prisliljen
# 5        bonitiranje      Odalen   ekovožnja      siljeno
# 6       asisitiranje    Møysalen   Jahalomin      siljeni
# 7          Citiranje   Roerdalen   nevarnost    Izsiljena
# 8      samocitiranje  tekmovalen      2,2-13      opiljen
# 9        meditiranje    vpadljiv     bojazen  neprisiljen

# %%
plotTSNE("FastText embeddings - t-SNE visualization", word_clusters, embedding_clusters, "SimilarWords - fastText - t-SNE_1.png")

# %%
plotMDS("Similar words - fastText [MDS]", word_clusters, embedding_clusters, "SimilarWords - fastText - MDS.png")

# %%
plotPCA("Similar words - fastText [PCA]", word_clusters, embedding_clusters, "SimilarWords - fastText - PCA.png")

# %% [markdown]
# ## Clustering

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %% [markdown]
# ### Kmeans

# %%
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))
range_clusters = list(range(2,15))
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")
# Out:
# 2 clusters - silhouette: 0.3816504180431366
# 3 clusters - silhouette: 0.3877662718296051
# 4 clusters - silhouette: 0.42452603578567505
# 5 clusters - silhouette: 0.3438163101673126
# 6 clusters - silhouette: 0.37362709641456604
# 7 clusters - silhouette: 0.3366203010082245
# 8 clusters - silhouette: 0.34353458881378174
# 9 clusters - silhouette: 0.3391488492488861
# 10 clusters - silhouette: 0.283881813287735
# 11 clusters - silhouette: 0.262967050075531
# 12 clusters - silhouette: 0.23182351887226105
# 13 clusters - silhouette: 0.20663480460643768
# 14 clusters - silhouette: 0.11695348471403122

# %%
num_clusters = 4
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
# Out:
# Wall time: 54.9 ms
# Clusters: [0, 0, 2, 0, 2, 1, 1, 3, 3, 2, 3, 2, 3, 1, 3]

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")
# Out:
# Cluster 0: ['seksizem' 'rasizem' 'homofobija']
# Cluster 1: ['sovražnost' 'vulgarnost' 'grožnja']
# Cluster 2: ['blatenje' 'žaljenje' 'nasilje' 'diskreditiranje']
# Cluster 3: ['bogokleten' 'nespodoben' 'benevolenten' 'napadalen' 'vsiljen']

# %% [markdown]
# ### Hierarchical clustering

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()
