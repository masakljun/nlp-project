# %% [markdown]
# # Noncontextual embeddings
#
# Notebook for Word2Vec Slovene language.

# %%
import gensim
import gensim.downloader
from sklearn.manifold import TSNE
from sklearn.manifold import MDS
from sklearn.decomposition import PCA
import numpy as np
import tempfile
import imageio
import shutil
import os
from statistics import mean
import pandas as pd 
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer 
from gensim.test.utils import datapath
from gensim.models.fasttext import load_facebook_vectors

from IPython.display import Image
from IPython.display import display
pd.options.display.max_columns = None

import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

# %%
import nltk

# %%
TOP_N = 10
KEYS = { \
    "seksizem": set(), 
    "rasizem": set(), 
    "blatenje": set(), 
    "homofobija": set(), 
    #"sovražni_govor": set(), 
    "nadlegovanje": set(), 
    "žaljenje": set(), 
    "sovražnost": set(), 
    "vulgarnost": set(), 
    "bogokletnost": set(), 
    "nespodobnost": set(), 
    "nasilje": set(), 
    "benevolentnost": set(), 
    "diskreditiranje": set(), 
    "napadalnost": set(),
    "grožnja": set(),
    "toksičnost": set(),
    #"vsiljenost": set(),
    #"spletno nasilje": set(),        
}

FIXED_KEYS = list(KEYS.keys())

# %%
import lemmagen.lemmatizer
from lemmagen.lemmatizer import Lemmatizer

lemmatizer = Lemmatizer(dictionary=lemmagen.DICTIONARY_SLOVENE)

from slovene_stemmer import stem

# %%
#lemmatizer = WordNetLemmatizer() 
#ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    #stem = ps.stem(key)
    st = stem([key])
    print(st)
    KEYS[key].add(lemma)
    KEYS[key].add(st[0])
    KEYS[key].add(key)
KEYS
# Out:
# ['seksiz']
# ['rasiz']
# ['blaten']
# ['homofob']
# ['nadleg']
# ['žaljen']
# ['sovraž']
# ['vulgar']
# ['bogoklet']
# ['nespodob']
# ['nasil']
# ['benev']
# ['diskredit']
# ['napad']
# ['grožn']
# ['toksič']
# {'seksizem': {'seksiz', 'seksizem'},
#  'rasizem': {'rasiz', 'rasizem'},
#  'blatenje': {'blaten', 'blatenje'},
#  'homofobija': {'homofob', 'homofobija'},
#  'nadlegovanje': {'nadleg', 'nadlegovanje'},
#  'žaljenje': {'žaljen', 'žaljenje'},
#  'sovražnost': {'sovraž', 'sovražnost'},
#  'vulgarnost': {'vulgar', 'vulgarnost'},
#  'bogokletnost': {'bogoklet', 'bogokletnost'},
#  'nespodobnost': {'nespodob', 'nespodobnost'},
#  'nasilje': {'nasil', 'nasilje'},
#  'benevolentnost': {'benev', 'benevolentnost'},
#  'diskreditiranje': {'diskredit', 'diskreditiranje'},
#  'napadalnost': {'napad', 'napadalnost'},
#  'grožnja': {'grožn', 'grožnja'},
#  'toksičnost': {'toksič', 'toksičnost'}}

# %%
def same_word(similar_word, ommit_words):
    similar_word = similar_word.replace("_", " ").replace("-", " ").lower()
    
    if similar_word in ommit_words:
        print(f"{ommit_words} -- {similar_word}")
        return True
    
    for ommit_word in ommit_words:
        if ommit_word in similar_word:
            print(f"{ommit_words} -- {similar_word}")
            return True
        
    return False

# %%
def getSimilarWords(model_gn):
    embedding_clusters = []
    word_clusters = []
    for key in FIXED_KEYS:
        ommit_words = KEYS[key]
        embeddings = []
        words = []
        for similar_word, _ in model_gn.most_similar(key, topn=TOP_N * 3):
            if not same_word(similar_word, ommit_words):
                words.append(similar_word)
                embeddings.append(model_gn[similar_word])
                
        if len(words) < TOP_N or len(embeddings) < TOP_N:
            print("ERROR")
            
        words = words[:TOP_N]
        embeddings = embeddings[:TOP_N]
        
        embedding_clusters.append(embeddings)
        word_clusters.append(words)
        
    return (word_clusters, embedding_clusters)

# %%
def displayDF(word_clusters):
    df = pd.DataFrame(dict(zip(FIXED_KEYS, word_clusters)))  
    display(df)

# %%
def plot_similar_words(title, labels, embedding_clusters, word_clusters, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=0.7, label=label)
        for i, word in enumerate(words):              
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=8)
        plt.annotate(label.upper(), alpha=1.0, xy=(mean(x), mean(y)), xytext=(0, 0),
            textcoords='offset points', ha='center', va='center', size=15)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(False)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
def plotTSNE(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotMDS(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = MDS(n_components=2, max_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotPCA(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = PCA(n_components=2, random_state = 32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plot_similar_words3d(title, labels, embedding_clusters, word_clusters, filename=None):
    fig = plt.figure(figsize=(16, 9))
    ax = fig.add_subplot(projection='3d')
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        z = embeddings[:, 2]
        ax.scatter(x, y,z, c=color, alpha=0.7, label=label)
        #for i, word in enumerate(words):              
            #plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
            #             textcoords='offset points', ha='right', va='bottom', size=8)
        #    plt.text(x,y,z, word, alpha=0.5,
        #                 textcoords='offset points', ha='right', va='bottom', size=8)
        #    ax.text(x,y,z, word, alpha=1.0,
        #        textcoords='offset points', ha='center', va='center', size=15)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(False)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
def plotMDS3D(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_3d = MDS(n_components=3, max_iter=3500, random_state=32)
    model_en_3d = model_en_3d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_3d = np.array(model_en_3d).reshape(n, m, 3)
    plot_similar_words3d(title, FIXED_KEYS, embeddings_en_3d, word_clusters, filename)

# %%
#model_gn = gensim.downloader.load('word2vec-google-news-300')
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
model = KeyedVectors.load_word2vec_format("models/model.bin", binary = True)

# %%
word_clusters_a, embedding_clusters = getSimilarWords(model)
# Out:
# {'seksizem', 'seksiz'} -- seksizma
# {'homofobija', 'homofob'} -- homofobijo
# {'nadleg', 'nadlegovanje'} -- nadlegovanja
# {'sovražnost', 'sovraž'} -- sovražnosti
# {'nasilje', 'nasil'} -- nasilja
# {'nasilje', 'nasil'} -- nasiljem
# {'nasilje', 'nasil'} -- nasilju
# {'nasilje', 'nasil'} -- nasilno
# {'grožnja', 'grožn'} -- grožnje
# {'grožnja', 'grožn'} -- grožnjo
# {'toksič', 'toksičnost'} -- toksična

# %%
displayDF(word_clusters_a)
# Out:
#         seksizem          rasizem      blatenje       homofobija  \
# 0   benevolenten  partnerjazenske       žalitev      ksenofobija
# 1      šovinizem  partnerjastrani      žaljenje         seksizem
# 2      mazohizem      ksenofobija     zmerjanje         seksizma
# 3    ksenofobija  homoseksualnost   licemerstvo   homoseksualcev
# 4      feminizem        terorizem     navzdolne        feminizem
# 5     homofobija        šovinizem  kritiziranje        šovinizem
# 6   antisocialno      narkomanija  natolcevanje  homoseksualnost
# 7    nekrofilija     konsenzualne    norčevanje        muslimank
# 8  socializirano       neonacizem       krsenje           kuffar
# 9        nasilje       pedofilija  demonizacijo          sadizem
#
#      nadlegovanje      žaljenje     sovražnost     vulgarnost bogokletnost  \
# 0         nasilje  kritiziranje    sumničavost   samovšečnost       metnih
# 1     šikaniranje      zaljenje     nezaupanje  prevarantstvo   požigalcev
# 2    ustrahovanje  zasmehovanje  brezobzirnost      otroškost  fallacijeva
# 3       posilstvo      blatenje      sovraštvo      banalnost     terjanja
# 4      trpinčenje     zmerjanje  prepirljivost  kategoričnega    prijetimi
# 5     poniževanje  primitivnost  zagrenjenosti     tragičnost   razselitev
# 6  diskriminacijo   poniževanje    napadalnost       smešnost     čudaštev
# 7       nemoralno     žaljivega     brezupnost   nihilistična   srečnejših
# 8      pretepanje       žalitev  prestopništvo     ranjenosti    hiltonovo
# 9         kaznivo   namigovanje    agresivnost  škodoželjnost    maščevano
#
#      nespodobnost            nasilje     benevolentnost diskreditiranje  \
# 0      tankočuten       nadlegovanje     nepartnerskega  administrirajo
# 1   metafikcijska       medvrstniško          nenačelna      asocialnih
# 2     obsesivnost          posilstvo          demosovih     servilnosti
# 3       govorčevo  intimnopartnersko           prostest         nacizme
# 4  avtoreferenčno             delikt    novonastajajoča      sramotitev
# 5      rahločuten         homofobijo          aferaštva       anarhične
# 6     erotizirana          sovraštvo        kanclerkine         sre~nih
# 7  razumljivostjo        poniževanje  protidemokratičen   perpetuiranje
# 8       liričnost     stigmatizacije         premetenca        cincanje
# 9       digresijo         nestrpnost         obstrukcij      _dejansko_
#
#         napadalnost          grožnja           toksičnost
# 0         nasilnost  izkoriščevalska           strupenost
# 1       agresivnost        naperjena   biorazpoložljivost
# 2      pritlikavost        nevarnost           mutagenost
# 3     prepirljivost         uperjena       desetilatrazin
# 4        brezupnost       sprevržena            bazičnost
# 5      nevrotičnost       nespametna           rezistenca
# 6  nepotrpežljivost        neizbežna     farmakokinetične
# 7        sovražnost          pretila            steviozid
# 8     prestrašenost            gonja  gastrointestinalnih
# 9       sumničavost          pomisel           karcinogen

# %%
plotMDS3D("Similar words - Word2Vec [MDS]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - MDS_3d.png")

# %%
plotTSNE("Word2Vec embeddings for Slovene language - t-SNE visualization", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - t-SNE_1 - Slovene.png")

# %%
plotMDS("Word2Vec embeddings for Slovene language - MDS visualization", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - MDS_1 - Slovene.png")

# %%
plotPCA("Word2Vec embeddings for Slovene language - PCA visualization", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - PCA_1 - Slovene.png")

# %% [markdown]
# ## Clustering

# %% [markdown]
# Compute average vectors from the embedding words

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %% [markdown]
# ### KMean

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

range_clusters = list(range(2,10))
avg = []
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    avg.append(silhouette_avg)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")
# Out:
# 2 clusters - silhouette: 0.6062533855438232
# 3 clusters - silhouette: 0.32397884130477905
# 4 clusters - silhouette: 0.30158963799476624
# 5 clusters - silhouette: 0.30396631360054016
# 6 clusters - silhouette: 0.30856630206108093
# 7 clusters - silhouette: 0.2430488020181656
# 8 clusters - silhouette: 0.27719932794570923
# 9 clusters - silhouette: 0.2198239415884018

# %%
plt.figure(figsize=(7, 2.8))
plt.plot(range_clusters, avg)
plt.title("Silhouette score - k-means clustering")
plt.xlabel("k")
plt.ylabel("silhouette score")
# Out:
# Text(0, 0.5, 'silhouette score')

# %%
num_clusters = 7
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
# Out:
# Wall time: 87.7 ms
# Clusters: [3, 3, 0, 3, 6, 0, 3, 4, 1, 1, 6, 4, 4, 1, 4, 5, 2, 1]

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")
# Out:
# Cluster 0: ['blatenje' 'žaljenje']
# Cluster 1: ['bogokleten' 'nespodoben' 'napadalen' 'vsiljen']
# Cluster 2: ['toksičen']
# Cluster 3: ['seksizem' 'rasizem' 'homofobija' 'sovražnost']
# Cluster 4: ['vulgarnost' 'benevolenten' 'diskreditiranje' 'sovražen']
# Cluster 5: ['grožnja']
# Cluster 6: ['nadlegovanje' 'nasilje']

# %% [markdown]
# ### Hierarhical clustering

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()

# %% [markdown]
# # fasttext

# %%
# Run first time only to download model
#import fasttext.util
#fasttext.util.download_model('en', if_exists='ignore')  # English
#ft = fasttext.load_model('cc.en.300.bin')

# %%
model_gn = load_facebook_vectors("models/cc.sl.300.bin.gz")

# %%
TOP_N = 20
KEYS = { \
    "seksizem": set(), 
    "rasizem": set(), 
    "blatenje": set(), 
    "homofobija": set(), 
    #"sovražni_govor": set(), 
    "nadlegovanje": set(), 
    "žaljenje": set(), 
    "sovražnost": set(), 
    "vulgarnost": set(), 
    "bogokletnost": set(), 
    "nespodobnost": set(), 
    "nasilje": set(), 
    "benevolentnost": set(), 
    "diskreditiranje": set(), 
    "napadalnost": set(),
    "grožnja": set(),
   # "toksičnost": set(),
    "vsiljenost": set(),
    #"spletno nasilje": set(),        
}


FIXED_KEYS = list(KEYS.keys())

# %%
import lemmagen.lemmatizer
from lemmagen.lemmatizer import Lemmatizer

lemmatizer = Lemmatizer(dictionary=lemmagen.DICTIONARY_SLOVENE)

from slovene_stemmer import stem

# %%
#lemmatizer = WordNetLemmatizer() 
#ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    #stem = ps.stem(key)
    st = stem([key])
    print(st)
    KEYS[key].add(lemma)
    KEYS[key].add(st[0])
    KEYS[key].add(key)
KEYS
# Out:
# ['seksiz']
# ['rasiz']
# ['blaten']
# ['homofob']
# ['nadleg']
# ['žaljen']
# ['sovraž']
# ['vulgar']
# ['bogoklet']
# ['nespodob']
# ['nasil']
# ['benev']
# ['diskredit']
# ['napad']
# ['grožn']
# ['vsilj']
# {'seksizem': {'seksiz', 'seksizem'},
#  'rasizem': {'rasiz', 'rasizem'},
#  'blatenje': {'blaten', 'blatenje'},
#  'homofobija': {'homofob', 'homofobija'},
#  'nadlegovanje': {'nadleg', 'nadlegovanje'},
#  'žaljenje': {'žaljen', 'žaljenje'},
#  'sovražnost': {'sovraž', 'sovražnost'},
#  'vulgarnost': {'vulgar', 'vulgarnost'},
#  'bogokletnost': {'bogoklet', 'bogokletnost'},
#  'nespodobnost': {'nespodob', 'nespodobnost'},
#  'nasilje': {'nasil', 'nasilje'},
#  'benevolentnost': {'benev', 'benevolentnost'},
#  'diskreditiranje': {'diskredit', 'diskreditiranje'},
#  'napadalnost': {'napad', 'napadalnost'},
#  'grožnja': {'grožn', 'grožnja'},
#  'vsiljenost': {'vsilj', 'vsiljenost'}}

# %%
word_clusters, embedding_clusters = getSimilarWords(model_gn)
word_clusters
# Out:
# {'seksizem', 'seksiz'} -- seksizem
# {'seksizem', 'seksiz'} -- cisseksizem
# {'seksizem', 'seksiz'} -- heteroseksizem
# {'seksizem', 'seksiz'} -- seksizmu
# {'seksizem', 'seksiz'} -- heteroseksizem
# {'seksizem', 'seksiz'} -- seksizma
# {'rasizem', 'rasiz'} -- rasizem
# {'rasizem', 'rasiz'} -- rasizma
# {'rasizem', 'rasiz'} -- rasizmu
# {'blatenje', 'blaten'} -- blatenje
# {'blatenje', 'blaten'} -- blatenjem
# {'blatenje', 'blaten'} -- blatenja
# {'blatenje', 'blaten'} -- blatenju
# {'homofobija', 'homofob'} -- homofobija
# {'homofobija', 'homofob'} -- homofobi
# {'homofobija', 'homofob'} -- homofobije
# {'homofobija', 'homofob'} -- homofobijo
# {'nadleg', 'nadlegovanje'} -- nadlegovanje
# {'nadleg', 'nadlegovanje'} -- nadlegovanja
# {'nadleg', 'nadlegovanje'} -- nadlegovane
# {'nadleg', 'nadlegovanje'} -- nadlegovanju
# {'nadleg', 'nadlegovanje'} -- nadlegovani
# {'nadleg', 'nadlegovanje'} -- nadlegovano
# {'nadleg', 'nadlegovanje'} -- nadlegovana
# {'nadleg', 'nadlegovanje'} -- nadlegovanega
# {'nadleg', 'nadlegovanje'} -- nadlegovan
# {'nadleg', 'nadlegovanje'} -- nadlegovanj
# {'nadleg', 'nadlegovanje'} -- nadlegovat
# {'nadleg', 'nadlegovanje'} -- nadlegovanih
# {'nadleg', 'nadlegovanje'} -- nadlegovanjem
# {'nadleg', 'nadlegovanje'} -- nadlegovalca
# {'nadleg', 'nadlegovanje'} -- nadlegovalce
# {'nadleg', 'nadlegovanje'} -- nadlegovati
# {'nadleg', 'nadlegovanje'} -- nadlegovalcev
# {'nadleg', 'nadlegovanje'} -- nadlegovalec
# {'nadleg', 'nadlegovanje'} -- nadlegovalcu
# {'nadleg', 'nadlegovanje'} -- nadlegoval
# {'nadleg', 'nadlegovanje'} -- nadlegovalna
# {'nadleg', 'nadlegovanje'} -- nadlegovala
# {'nadleg', 'nadlegovanje'} -- nadlegovalci
# {'nadleg', 'nadlegovanje'} -- nadlegovalo
# {'nadleg', 'nadlegovanje'} -- nadlego
# {'nadleg', 'nadlegovanje'} -- nadlegovalcem
# {'nadleg', 'nadlegovanje'} -- nadlegovale
# {'nadleg', 'nadlegovanje'} -- nadlegovali
# {'nadleg', 'nadlegovanje'} -- 6 stopenj spolnega nadlegovanja 2813
# {'nadleg', 'nadlegovanje'} -- nadlege
# {'nadleg', 'nadlegovanje'} -- nadlegujem
# {'nadleg', 'nadlegovanje'} -- nadlegujemo
# {'nadleg', 'nadlegovanje'} -- nadleguje
# {'nadleg', 'nadlegovanje'} -- nadlegujejo
# {'nadleg', 'nadlegovanje'} -- nadlegujte
# {'nadleg', 'nadlegovanje'} -- nadlegujete
# {'nadleg', 'nadlegovanje'} -- nadlega
# {'nadleg', 'nadlegovanje'} -- nadlegovalci
# {'nadleg', 'nadlegovanje'} -- nadlegovalne
# {'žaljenje', 'žaljen'} -- razžaljenje
# {'žaljenje', 'žaljen'} -- žaljenje
# {'žaljenje', 'žaljen'} -- žaljenju
# {'žaljenje', 'žaljen'} -- užaljenost
# {'žaljenje', 'žaljen'} -- žaljenja
# {'žaljenje', 'žaljen'} -- žaljeno
# {'žaljenje', 'žaljen'} -- žaljenjem
# {'žaljenje', 'žaljen'} -- žaljeni
# {'sovražnost', 'sovraž'} -- sovražnost
# {'sovražnost', 'sovraž'} -- agresivnost sovražnost
# {'sovražnost', 'sovraž'} -- sovražnostjo
# {'sovražnost', 'sovraž'} -- agresivnost sovražnost
# {'sovražnost', 'sovraž'} -- sovražnosti
# {'sovražnost', 'sovraž'} -- sovražnostih
# {'sovražnost', 'sovraž'} -- agresivnostjo sovražnostjo
# {'sovražnost', 'sovraž'} -- agresivnosti sovražnosti
# {'sovražnost', 'sovraž'} -- sovražnostim
# {'sovražnost', 'sovraž'} -- sovražnostmi
# {'sovražnost', 'sovraž'} -- sovražnosti
# {'sovražnost', 'sovraž'} -- sovražtva
# {'sovražnost', 'sovraž'} -- sovražno
# {'sovražnost', 'sovraž'} -- sovražneje
# {'sovražnost', 'sovraž'} -- sovražnico
# {'vulgar', 'vulgarnost'} -- vulgarnostjo
# {'vulgar', 'vulgarnost'} -- vulgarnosti
# {'vulgar', 'vulgarnost'} -- vulgarizacija
# {'vulgar', 'vulgarnost'} -- vulgarno
# {'vulgar', 'vulgarnost'} -- vulgarna
# {'vulgar', 'vulgarnost'} -- vulgarizem
# {'vulgar', 'vulgarnost'} -- vulgar
# {'bogokletnost', 'bogoklet'} -- bogokletnosti
# {'bogokletnost', 'bogoklet'} -- bogokletno
# {'bogokletnost', 'bogoklet'} -- bogokletje
# {'bogokletnost', 'bogoklet'} -- bogokletstvo
# {'bogokletnost', 'bogoklet'} -- bogokletnik
# {'bogokletnost', 'bogoklet'} -- bogokletstva
# {'bogokletnost', 'bogoklet'} -- bogokletneža
# {'nespodobnost', 'nespodob'} -- nespodobnosti
# {'nespodobnost', 'nespodob'} -- nespodobnostmi
# {'nespodobnost', 'nespodob'} -- nespodobni
# {'nespodobnost', 'nespodob'} -- nespodoben
# {'nespodobnost', 'nespodob'} -- nespodobno
# {'nespodobnost', 'nespodob'} -- nespodobnega
# {'nespodobnost', 'nespodob'} -- nespodobna
# {'nespodobnost', 'nespodob'} -- nespodobne
# {'nasilje', 'nasil'} -- nasilje
# {'nasilje', 'nasil'} -- nasilj
# {'nasilje', 'nasil'} -- nenasilje
# {'nasilje', 'nasil'} -- nasiljem
# {'nasilje', 'nasil'} -- nenasilje
# {'nasilje', 'nasil'} -- nasilja
# {'nasilje', 'nasil'} -- nasiljem
# {'nasilje', 'nasil'} -- nasilji
# {'nasilje', 'nasil'} -- nasilja.
# {'nasilje', 'nasil'} -- nasilništvo
# {'nasilje', 'nasil'} -- nasiljatrg
# {'nasilje', 'nasil'} -- nasilneži
# {'nasilje', 'nasil'} -- nasilneže
# {'nasilje', 'nasil'} -- nasilstvo
# {'nasilje', 'nasil'} -- nasilju
# {'nasilje', 'nasil'} -- 5 2 2013 dr milko mikola n rde e nasilje
# {'nasilje', 'nasil'} -- nasiljih
# {'nasilje', 'nasil'} -- nasilj
# {'nasilje', 'nasil'} -- nasilno
# {'nasilje', 'nasil'} -- nasilnost
# {'nasilje', 'nasil'} -- nenasilj
# {'nasilje', 'nasil'} -- nasiljena
# {'nasilje', 'nasil'} -- nasilk
# {'nasilje', 'nasil'} -- nenasiljem
# {'nasilje', 'nasil'} -- nasilnežu
# {'nasilje', 'nasil'} -- nasilneža
# {'nasilje', 'nasil'} -- nasilnike
# {'nasilje', 'nasil'} -- nasilništva
# {'nasilje', 'nasil'} -- nasilniško
# {'nasilje', 'nasil'} -- ne nasiljem
# {'nasilje', 'nasil'} -- nasilnežem
# {'nasilje', 'nasil'} -- nasilnežev
# {'nasilje', 'nasil'} -- nasilništvom
# {'nasilje', 'nasil'} -- nasilstev
# {'nasilje', 'nasil'} -- nasilništvo
# {'benevolentnost', 'benev'} -- benevolentno
# {'diskredit', 'diskreditiranje'} -- diskreditiranja
# {'diskredit', 'diskreditiranje'} -- diskreditirani
# {'diskredit', 'diskreditiranje'} -- diskreditirana
# {'diskredit', 'diskreditiranje'} -- diskreditiran
# {'diskredit', 'diskreditiranje'} -- diskreditacijo
# {'diskredit', 'diskreditiranje'} -- diskreditirat
# {'diskredit', 'diskreditiranje'} -- diskreditira
# {'diskredit', 'diskreditiranje'} -- diskreditirajo
# {'diskredit', 'diskreditiranje'} -- diskreditirali
# {'diskredit', 'diskreditiranje'} -- diskreditiral
# {'diskredit', 'diskreditiranje'} -- diskreditiralo
# {'diskredit', 'diskreditiranje'} -- diskreditirati
# {'diskredit', 'diskreditiranje'} -- diskreditirala
# {'diskredit', 'diskreditiranje'} -- diskreditirajoči
# {'diskredit', 'diskreditiranje'} -- diskreditacije
# {'diskredit', 'diskreditiranje'} -- diskreditacija
# {'napadalnost', 'napad'} -- nenapadalnost
# {'napadalnost', 'napad'} -- napadalnostjo
# {'napadalnost', 'napad'} -- napadalnosti
# {'napadalnost', 'napad'} -- napadalno
# {'napadalnost', 'napad'} -- napadalna
# {'napadalnost', 'napad'} -- napadalka
# {'napadalnost', 'napad'} -- napadalko
# {'napadalnost', 'napad'} -- napadalneje
# {'napadalnost', 'napad'} -- napadalne
# {'napadalnost', 'napad'} -- napadalki
# {'napadalnost', 'napad'} -- napadalčev
# {'napadalnost', 'napad'} -- napadalnih
# {'napadalnost', 'napad'} -- obrambno napadalne
# {'napadalnost', 'napad'} -- napadalke
# {'napadalnost', 'napad'} -- nenapadalna
# {'grožnja', 'grožn'} -- grožnj
# {'grožnja', 'grožn'} -- grožnjami11.
# {'grožnja', 'grožn'} -- grožnja
# {'grožnja', 'grožn'} -- grožnjami.več
# {'grožnja', 'grožn'} -- grožnje.
# {'grožnja', 'grožn'} -- grožnjam
# {'grožnja', 'grožn'} -- grožnjaokolju
# {'grožnja', 'grožn'} -- grožnjah
# {'grožnja', 'grožn'} -- grožnje
# {'grožnja', 'grožn'} -- grožnji
# {'grožnja', 'grožn'} -- grožnjo
# {'grožnja', 'grožn'} -- grožnjami
# {'grožnja', 'grožn'} -- grožno
# {'grožnja', 'grožn'} -- grožnjaju
# {'grožnja', 'grožn'} -- grožnje
# {'vsiljenost', 'vsilj'} -- vsiljenje
# {'vsiljenost', 'vsilj'} -- vsiljivost
# {'vsiljenost', 'vsilj'} -- vsiljenega
# {'vsiljenost', 'vsilj'} -- vsiljenec
# {'vsiljenost', 'vsilj'} -- vsiljena
# [['Bruksizem',
#   'Rasizem',
#   'bruksizem',
#   'fasizem',
#   'mačizem',
#   'seksualizem',
#   'Sizeizem',
#   'rasizem',
#   'krausizem',
#   'fetišizem',
#   'solipsizem',
#   'sizeizem',
#   'specisizem',
#   'Reizem',
#   'Sadizem',
#   'bahaizem',
#   'seksistični',
#   'izem',
#   'slengizem',
#   'panpsihizem'],
#  ['fasizem',
#   'Bruksizem',
#   'krausizem',
#   'bruksizem',
#   'seksizem',
#   'izem',
#   'Tačizem',
#   'Seksizem',
#   'snobizem',
#   'Sizeizem',
#   'amygizem',
#   'mohizem',
#   'pučizem',
#   'tahizem',
#   'panpsihizem',
#   'mazohizem',
#   'evfuizem',
#   'atavizem',
#   'Reizem',
#   'ramizem'],
#  ['klatenje',
#   'platenje',
#   'mlatenje',
#   'zlatenje',
#   'Ihtenje',
#   'tenje',
#   'ihtenje',
#   'Drhtenje',
#   'črtenje',
#   'Zlatenje',
#   'Genje',
#   'kratenje',
#   'netenje',
#   'vpraĹĄanje',
#   'Slutenje',
#   'Netenje',
#   'bohotenje',
#   'Obzhutenje',
#   'gomazenje',
#   'bentenje'],
#  ['fazmofobija',
#   'dromofobija',
#   'ginofobija',
#   'Kromofobija',
#   'Bifobija',
#   'Kemofobija',
#   'lalofobija',
#   'tafofobija',
#   'zoofobija',
#   'osmofobija',
#   'fobofobija',
#   'aglofobija',
#   'cibofobija',
#   'misofobija',
#   'hemofobija',
#   'ofidiofobija',
#   'Arahnofobija',
#   'Nozofobija',
#   'entomofobija',
#   'fonofobija'],
#  ['Ustrahovanje',
#   'ustrahovanje',
#   'šikaniranje',
#   'nasilje',
#   'drogiranje',
#   'Trpinčenje',
#   'zalezovanje',
#   'posiljevanje',
#   'diskriminiranje',
#   'psovanje',
#   'žaljenje',
#   'zlorabljanje',
#   'vsiljevanje',
#   'Namigovanje',
#   'poniževanje',
#   'trpinčenje',
#   'diskriminacijo',
#   'mobing',
#   'lezbijstvo',
#   'zastrahovanje'],
#  ['šaljenje',
#   'žvaljenje',
#   'hvaljenje',
#   'samohvaljenje',
#   'razgaljenje',
#   'Škíljenje',
#   'mazíljenje',
#   'AWB-janje',
#   'buljenje',
#   'naalkaljenje',
#   '-taljenje',
#   'Zrcáljenje',
#   'omalovaževanje',
#   'Siljenje',
#   'Tuljenje',
#   'kritiziranje',
#   'živlljenje',
#   'godrnjanje',
#   'jokcanje',
#   'ŽIvljenje'],
#  ['Vzdražnost',
#   'lažnost',
#   'vzdražnost',
#   'Važnost',
#   'užaljenost',
#   'žnost',
#   'moĹžnost',
#   'Vlážnost',
#   'Kúžnost',
#   'konfliktnost',
#   'nasilnost',
#   'Otožnost',
#   'mehkužnost',
#   'posesivnost',
#   'nenaklonjenost',
#   'udanost',
#   'Téžnost',
#   'nastrojenost',
#   'brezkužnost',
#   'plašnost'],
#  ['arnost',
#   'Imúnost',
#   'političnost',
#   'bizarnost',
#   'Psévdoznánost',
#   'družbenost',
#   'zoprnost',
#   'Slánost',
#   'brezléčnost',
#   'prav-nost',
#   'lnost',
#   'Polárnost',
#   'hipnost',
#   'znanstvenost',
#   'budoucnost',
#   'znánost',
#   'odurnost',
#   'vanrnost',
#   'Znánost',
#   'Várnost'],
#  ['nedoletnost',
#   'etnost',
#   'nadumetnost',
#   'Akútnost',
#   'koketnost',
#   'konkretnost',
#   'strahopetnost',
#   'nespametnost',
#   'ANSI-umetnost',
#   'Spametnost',
#   'neverjetnost',
#   'neumrjočnost',
#   'neumetnost',
#   'mladoletnost',
#   'inteligetnost',
#   'Smŕtnost',
#   'Mogućnost',
#   'druge.Umetnost',
#   'n.pr.umetnost',
#   'prevzetnost'],
#  ['spodobnost',
#   'bogopodobnost',
#   'Spodobnost',
#   'zadobnost',
#   'spodobnostjo',
#   'prav-nost',
#   'brezsramnost',
#   'lenobnost',
#   'neudobnost',
#   'hudobnost',
#   'nespornost',
#   'brezkužnost',
#   'Udobnost',
#   'samopodobnost',
#   'spodobnosti',
#   'skricnost',
#   'brezléčnost',
#   'resnicnost',
#   'nesproščenost',
#   'turobnost'],
#  ['zlorabljanje',
#   'Ustrahovanje',
#   'ustrahovanje',
#   'nadlegovanje',
#   'posiljevanje',
#   'Izsiljevanje',
#   'vsiljevanje',
#   'silje',
#   'izsiljevanje',
#   'zlorabljeno',
#   'zlorabo.Polno',
#   'šikaniranje',
#   'inkriminacijo',
#   'Nadlegovanje',
#   'Vsiljevanje',
#   'zlorabo',
#   'pornografijo',
#   'zastrahovanje',
#   'drogiranje',
#   'seksulano'],
#  ['Ekvipolentnost',
#   'ekvipolentnost',
#   'somnolentnost',
#   'fluentnost',
#   'Dlinkventnost',
#   'valentnost',
#   'lasntnost',
#   'Agentnost',
#   'delikventnost',
#   'surgentnost',
#   'Akútnost',
#   'Idempoténtnost',
#   'Nilpotentnost',
#   'dementnost',
#   'štirivalentnost',
#   'virulentnost',
#   'impotentnost',
#   'Idempotentnost',
#   'Solventnost',
#   'ambivalentnost'],
#  ['akreditiranje',
#   'mikrokreditiranje',
#   'kreditiranje',
#   'Kreditiranje',
#   'agitiranje',
#   'bonitiranje',
#   'asisitiranje',
#   'Citiranje',
#   'samocitiranje',
#   'meditiranje',
#   'rcitiranje',
#   'dololčevanje',
#   'iztiranje',
#   'Bonitiranje',
#   'Vtiranje',
#   'editiranje',
#   'skvotiranje',
#   'legitimiranje',
#   'upravičevanje',
#   'justiranje'],
#  ['alnost',
#   'udarnost',
#   'razdiralnost',
#   'tekmavalnost',
#   'uničevalnost',
#   'kalnost',
#   'socialnost',
#   'strupénost',
#   'bipedalnost',
#   'lnost',
#   'somodalnost',
#   'nasilnost',
#   'pretkanost',
#   'centralnost',
#   'zakrčenost',
#   'elitarnost',
#   'igralnost',
#   'izzivalnost',
#   'plavalnost',
#   'radikalnost'],
#  ['Požnja',
#   'voĹžnja',
#   'grožja',
#   'Mržnja',
#   '-nevarnost',
#   'ekovožnja',
#   'Jahalomin',
#   'nevarnost',
#   '2,2-13',
#   'bojazen',
#   'podatkov.Varnost',
#   'resna',
#   'ranljivost',
#   'globalnost',
#   'grozečo',
#   'dokazAkcija',
#   'kriptacija',
#   'krizaaretacija',
#   'invazija',
#   'grozila'],
#  ['oddáljenost',
#   'izpiljenost',
#   'Ožiljenost',
#   'prisiljenost',
#   'vseenost',
#   'ukrívljenost',
#   'Precépljenost',
#   'zaksrbljenost',
#   'izrabljenost',
#   'jesamodjenost',
#   'priravljenost',
#   'vinjenost',
#   'usojenost',
#   'Obremenjenost',
#   'zatopljenost',
#   'ljubljenost',
#   'zgrbljenost',
#   'prenasljenost',
#   'dovoljenost',
#   'nakljonjenost']]

# %%
displayDF(word_clusters)
# Out:
#        seksizem      rasizem    blatenje    homofobija     nadlegovanje  \
# 0     Bruksizem      fasizem    klatenje   fazmofobija     Ustrahovanje
# 1       Rasizem    Bruksizem    platenje   dromofobija     ustrahovanje
# 2     bruksizem    krausizem    mlatenje    ginofobija      šikaniranje
# 3       fasizem    bruksizem    zlatenje   Kromofobija          nasilje
# 4       mačizem     seksizem     Ihtenje      Bifobija       drogiranje
# 5   seksualizem         izem       tenje    Kemofobija       Trpinčenje
# 6      Sizeizem      Tačizem     ihtenje    lalofobija      zalezovanje
# 7       rasizem     Seksizem    Drhtenje    tafofobija     posiljevanje
# 8     krausizem     snobizem     črtenje     zoofobija  diskriminiranje
# 9     fetišizem     Sizeizem    Zlatenje    osmofobija         psovanje
# 10   solipsizem     amygizem       Genje    fobofobija         žaljenje
# 11     sizeizem      mohizem    kratenje    aglofobija     zlorabljanje
# 12   specisizem      pučizem     netenje    cibofobija      vsiljevanje
# 13       Reizem      tahizem  vpraĹĄanje    misofobija      Namigovanje
# 14      Sadizem  panpsihizem    Slutenje    hemofobija      poniževanje
# 15     bahaizem    mazohizem     Netenje  ofidiofobija       trpinčenje
# 16  seksistični     evfuizem   bohotenje  Arahnofobija   diskriminacijo
# 17         izem     atavizem  Obzhutenje    Nozofobija           mobing
# 18    slengizem       Reizem   gomazenje  entomofobija       lezbijstvo
# 19  panpsihizem      ramizem    bentenje    fonofobija    zastrahovanje
#
#           žaljenje      sovražnost     vulgarnost    bogokletnost  \
# 0         šaljenje      Vzdražnost         arnost     nedoletnost
# 1        žvaljenje         lažnost        Imúnost          etnost
# 2        hvaljenje      vzdražnost    političnost     nadumetnost
# 3    samohvaljenje         Važnost      bizarnost        Akútnost
# 4      razgaljenje      užaljenost  Psévdoznánost       koketnost
# 5        Škíljenje           žnost     družbenost     konkretnost
# 6       mazíljenje        moĹžnost       zoprnost   strahopetnost
# 7        AWB-janje        Vlážnost        Slánost    nespametnost
# 8         buljenje         Kúžnost    brezléčnost   ANSI-umetnost
# 9     naalkaljenje    konfliktnost      prav-nost      Spametnost
# 10       -taljenje       nasilnost          lnost    neverjetnost
# 11      Zrcáljenje        Otožnost      Polárnost    neumrjočnost
# 12  omalovaževanje      mehkužnost        hipnost      neumetnost
# 13        Siljenje     posesivnost   znanstvenost    mladoletnost
# 14        Tuljenje  nenaklonjenost     budoucnost   inteligetnost
# 15    kritiziranje         udanost        znánost        Smŕtnost
# 16      živlljenje         Téžnost       odurnost       Mogućnost
# 17      godrnjanje    nastrojenost       vanrnost  druge.Umetnost
# 18        jokcanje     brezkužnost        Znánost   n.pr.umetnost
# 19       ŽIvljenje        plašnost        Várnost     prevzetnost
#
#      nespodobnost        nasilje   benevolentnost    diskreditiranje  \
# 0      spodobnost   zlorabljanje   Ekvipolentnost      akreditiranje
# 1   bogopodobnost   Ustrahovanje   ekvipolentnost  mikrokreditiranje
# 2      Spodobnost   ustrahovanje    somnolentnost       kreditiranje
# 3       zadobnost   nadlegovanje       fluentnost       Kreditiranje
# 4    spodobnostjo   posiljevanje    Dlinkventnost         agitiranje
# 5       prav-nost   Izsiljevanje       valentnost        bonitiranje
# 6    brezsramnost    vsiljevanje        lasntnost       asisitiranje
# 7       lenobnost          silje        Agentnost          Citiranje
# 8      neudobnost   izsiljevanje    delikventnost      samocitiranje
# 9       hudobnost    zlorabljeno      surgentnost        meditiranje
# 10     nespornost  zlorabo.Polno         Akútnost         rcitiranje
# 11    brezkužnost    šikaniranje   Idempoténtnost       dololčevanje
# 12       Udobnost  inkriminacijo    Nilpotentnost          iztiranje
# 13  samopodobnost   Nadlegovanje       dementnost        Bonitiranje
# 14    spodobnosti    Vsiljevanje  štirivalentnost           Vtiranje
# 15      skricnost        zlorabo     virulentnost         editiranje
# 16    brezléčnost   pornografijo     impotentnost        skvotiranje
# 17     resnicnost  zastrahovanje   Idempotentnost      legitimiranje
# 18  nesproščenost     drogiranje      Solventnost      upravičevanje
# 19      turobnost      seksulano   ambivalentnost         justiranje
#
#      napadalnost           grožnja     vsiljenost
# 0         alnost            Požnja    oddáljenost
# 1       udarnost           voĹžnja    izpiljenost
# 2   razdiralnost            grožja     Ožiljenost
# 3   tekmavalnost            Mržnja   prisiljenost
# 4   uničevalnost        -nevarnost       vseenost
# 5        kalnost         ekovožnja   ukrívljenost
# 6     socialnost         Jahalomin  Precépljenost
# 7     strupénost         nevarnost  zaksrbljenost
# 8    bipedalnost            2,2-13   izrabljenost
# 9          lnost           bojazen  jesamodjenost
# 10   somodalnost  podatkov.Varnost  priravljenost
# 11     nasilnost             resna      vinjenost
# 12    pretkanost        ranljivost      usojenost
# 13   centralnost        globalnost  Obremenjenost
# 14    zakrčenost           grozečo   zatopljenost
# 15    elitarnost       dokazAkcija    ljubljenost
# 16     igralnost        kriptacija    zgrbljenost
# 17   izzivalnost    krizaaretacija  prenasljenost
# 18    plavalnost          invazija    dovoljenost
# 19   radikalnost           grozila  nakljonjenost

# %%
plotTSNE("FastText embeddings for Slovene language - t-SNE visualization", word_clusters, embedding_clusters, "SimilarWords - fastText - t-SNE_1 - Slovene.png")

# %%
plotMDS("FastText embeddings for Slovene language - MDS visualization", word_clusters, embedding_clusters, "SimilarWords - fastText - MDS - Slovene.png")

# %%
plotPCA("FastText embeddings for Slovene language - PCA visualization", word_clusters, embedding_clusters, "SimilarWords - fastText - PCA - Slovene.png")

# %% [markdown]
# ## Clustering

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %% [markdown]
# ### Kmeans

# %%
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))
range_clusters = list(range(2,15))
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")
# Out:
# 2 clusters - silhouette: 0.3816504180431366
# 3 clusters - silhouette: 0.3877662718296051
# 4 clusters - silhouette: 0.42452603578567505
# 5 clusters - silhouette: 0.3438163101673126
# 6 clusters - silhouette: 0.3341917097568512
# 7 clusters - silhouette: 0.3477233350276947
# 8 clusters - silhouette: 0.34353458881378174
# 9 clusters - silhouette: 0.3391488492488861
# 10 clusters - silhouette: 0.283881813287735
# 11 clusters - silhouette: 0.262967050075531
# 12 clusters - silhouette: 0.23182351887226105
# 13 clusters - silhouette: 0.20663480460643768
# 14 clusters - silhouette: 0.11695348471403122

# %%
num_clusters = 4
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
# Out:
# Wall time: 23.5 ms
# Clusters: [0, 0, 3, 0, 3, 2, 2, 1, 1, 3, 1, 3, 1, 2, 1]

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")
# Out:
# Cluster 0: ['seksizem' 'rasizem' 'homofobija']
# Cluster 1: ['bogokleten' 'nespodoben' 'benevolenten' 'napadalen' 'vsiljen']
# Cluster 2: ['sovražnost' 'vulgarnost' 'grožnja']
# Cluster 3: ['blatenje' 'žaljenje' 'nasilje' 'diskreditiranje']

# %% [markdown]
# ### Hierarchical clustering

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()
