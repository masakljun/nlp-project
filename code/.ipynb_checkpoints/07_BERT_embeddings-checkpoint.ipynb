# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np

# %% [markdown]
# Read the data

# %%
data = pd.read_csv("dataset/data.csv", sep = ";")
data.head()
# Out:
#                                                 text    label
# 0  fucks sake go away stupid anon — ^  https://t....  abusive
# 1  Damn dean just put Corbin to sleep. That Match...  abusive
# 2  @TheRealCamerota THAT BEER BUYING FREAKING IDI...  abusive
# 3  what idiot called them antacids and not afterb...  abusive
# 4  RT @gogglepossum: Don't you hate people that p...  abusive

# %% [markdown]
# Preprocess the dataset

# %%
def preprocess(A, labels):
    B = []
    labels_new = []
    for i in range(len(A)):

        text = A[i]
        # remove old style retweet text "RT"
        text = re.sub(r'^RT[\s]+', '', text)

        # remove hyperlinks
        text= re.sub(r'https?:\/\/.*[\r\n]*', '', text)

        # remove hashtags
        # only removing the hash # sign from the word
        text = re.sub(r'#', '', text)

        # remove tagging @
        text = re.sub(r"(?:\@|https?\://)\S+", "", text)

        # remove new line \n
        text = re.sub("\n", "", text)
        
        # remove numbers
        text = text.replace("[0-9]", " ")
    
        # to lower case
        text = text.lower()

        # remove zero length tweets
        if(len(text) == 0 ):
            continue

        B.append(text)
        labels_new.append(labels[i])
    return B, labels_new

# %%
texts, labels = preprocess(data["text"], data["label"])
len(texts)
# Out:
# 57581

# %% [markdown]
# Import the model

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens', 'cuda')

#model = SentenceTransformer('distilbert-base-nli-mean-tokens', "cuda")

model.max_seq_length = 512

# %%
#ids = np.random.choice(list(range(len(texts))), size = 57581)
ids = np.arange(0, len(texts))
ids = np.sort(ids)
l = np.array(labels)[ids]
t = np.array(texts)[ids]
ids = np.argsort(l)
l = l[ids]
t = t[ids]
l
# Out:
# array(['abusive', 'abusive', 'abusive', ..., 'toxic', 'toxic', 'toxic'],
#       dtype='<U12')

# %%
texts
# Out:
# ['fucks sake go away stupid anon — ^  ',
#  'damn dean just put corbin to sleep. that match also showed why it was on pre show. boring as fuck',
#  ' that beer buying freaking idiot thinks trump leaked it to nail rice? are you kidding? and sacrifice flynn. mud is appropo',
#  'what idiot called them antacids and not afterburners',
#  " don't you hate people that put salt on their bag of dicks before even trying them?",
#  'you worried about somebody bein ugly... bitch you ugly...',
#  'holy crap!! the biggest assclown of a mayor on  pulling race card!! get his ass outta office!!! draintheswamp',
#  ' i just want to cry so fucking bad look at them ',
#  'yooooo vans got these sick ass velvet oxblood slip onnnnssssss 💦💦💦💦👅👅👅👅',
#  ' disgusting. insulting. parks are not a charity. give them a fucking budget, asshole.  theresistance…',
#  ' i swear every person that voted for tru💩 is a fucking moron!! impeachtrump notmypresident   stillwithher trumprussiaco…',
#  "don't sleep with me? then don't speak with me. and never talk bad bout niggas that eat with me",
#  'niggas don\'t lie, our ugly friend put up a pic we just gon write "nigga u ugly" under it',
#  " april fools fucking dope if you ain't feeling this than you have rigor mortis, dummy!! hiphop boombap goldenera… ",
#  '  are u still rocking with that team btw nani is fucking sick i tried him',
#  " 2. i'm a bad bitch you can't kill me ",
#  ' bruh i fucking hate people like this 😤 ',
#  'im so fucking sick of seeing this damn tweet. ',
#  ' jesus, the get out sequel looks fucking terrifying ',
#  ' hella is from the bay....and majority of la bitches hate on the word hella 😂😩 ',
#  " that's what u fucking get for pushing that dog!!!!!!!!! ",
#  ' police holds me. anoda police ask "officer weytin him do" he replies d idiot pis for here. d oda says hold d idiot mak…',
#  'theres a difference between marketing and being fucking annoying',
#  'we miss yo ugly sid the the sloth , dur yes dur saying ass too ',
#  "these fucking butn scars on my chest is so ugly! i can't even wear a shirt without having it zipped all the way up or a scarf on.",
#  'ancyl there this idiot of cosas speaking, i think hate speech will come out of his speech if he doesnt stop.',
#  ' &amp; some idiots of my country think and this regime is working to bring uniform civil code.let them bring uniform beef consu…',
#  ' and idiots spend $8.99 for a bag of skittles. ',
#  'fuck you and die: an oral history of something awful',
#  'its not tht i hate the place even tho i dont like it but i hate the ppl who havent done anything to the bullshit tht happened.',
#  'i hate when people get up here and tell what happening on a tv show or movie... shut yo ass up 😂',
#  "my fucking god  don't die!! backflips like a cruiserweight in his prime at 47!! 😳😳 wrestlemania",
#  '💀 yk them hoes ugly sis. 🤦🏽\u200d♀️ ',
#  "he would not have won if the dnc knew what the hell they were doing. it's too bad if saying that hurts feelings, but trump's gotta go",
#  " don't take out the anger of being a hairless nigga on us. .. ",
#  " one thing i hate about spring/summer is the bloody birds waking me up at 6am. it's like world war 3 out there🙃",
#  ' i will go to bat for you!!! what the hell is wrong with people!! also ily',
#  'hopefully all fathers and mothers tell they daughghters ben dover and his friends are evil cunts',
#  'niggas worst than your side bitch always questioning they position',
#  " that's an ugly ass house to be paying $5mil for ",
#  ' i am trying to avoid using the word hate but i fucking hate donald trump.',
#  "it's always the filthy bitch that comes in the picture.. 🤦🏽\u200d♂️",
#  " omg i can't believe someone would wish that on anyone never mind a baby the sick bitch",
#  " it's the fucking redemptiontour !!!! go fucking heels ",
#  "quit fucking spamming me with this crap it don't work ",
#  ' the number 1 angel shows are gonna be fucking wiiiiild!!  opening in sf &amp; ny with  joining in n…',
#  '  sanders said "i\'m sick of talking about your damned emails"',
#  'i just want gordon ramsay to call me an idiot sandwich',
#  '  r u dump or u r too stupid idiot',
#  "rick james fucking hated prince (who i have pledged all of my allegiance to) but it doesn't keep me from appreciating james' eccentricities.",
#  ' who will be the 1st gop rep to find some guts and stand up to the idiot in the wh? firethefool ',
#  " just block him. . .he's fucking dreadful.",
#  'when guys talk to me i just wanna go sleep, boring ass conversation',
#  ' gotta make the  freshman this year or everyone retarded',
#  ' im a nasty ass freak when i like you..',
#  '  can you count its 1-3 idiot💯',
#  ' i fucking hate you ',
#  'watching this annoying ass man makes me want to never eat another pizza...... my600lblife tlc',
#  ' you know when youre fucking stupid and get one question in math correct and think ur albert fucking einstein because me t…',
#  ' she does &amp; tori is an idiot for taking it all the time',
#  ' look at this fuckin retard ',
#  " mf's be having me fucked up alll the time !🤦🏽\u200d♀️",
#  ' you bunch of ass clowns are as bad as the illegitimate pres we got stuck with. leaders in bs news. worstpresever',
#  " pip is an idiot - and needs to tell the truth...... and why didn't she realise before? thearchers",
#  ' so this dude bombed syria!!!! idiot',
#  ' son this nigga is the worst ',
#  ' "attack dog" us media meekly kowtows to noted idiot trump after show of force, like timid piglets cowering before a wolf wit…',
#  '  i wish she would move to montana so she could be my senator instead of that idiot steve daines',
#  '. so sick of this altmedia bullshit fakenews syriastrikes syriahoax . . to be woke you must 👉 thinkforyourself… ',
#  ' hate a nigga that try and run me, "you can\'t wear this, you can\'t go out, you can\'t chill with them" likeeeeee is u my man or…',
#  " oh hal! 😱😂😳what is dogs' hold over idiots like us? 🙄",
#  'i put the js on the hoes look clueless i put the designers on the hoes get stupid truestory',
#  'see clapbacks 👏👏👏 may i reach this level of being bad ass 😅 ',
#  ' so sick of assadists stalking my account piss off blocked! ',
#  ' what the triple fuck!!!! what the hell is going on?',
#  ' isis: "us being run by an idiot\' ',
#  " omg! i can't fucking spell! muckbang, also, play overwatch",
#  "you a bad bitch don't eva forget that ",
#  ' all these fuckers who thought email and a nebulous speech to goldman sachs were disqualifying look real fucking petty and…',
#  ' brooooo fuuuuccckkk that submission spot was fucking insane!!',
#  'go cry yo ass to sleep , cuz stupid bitch yk he lying !!',
#  'talamabout going to dates with your filters. no wonder that nigga was disappointed 😂😂😂😂😂😂😂',
#  "if you don't want my puppy jumping on your dog, don't fucking bring him in my yard where my puppy is playing. stupid bitch.",
#  'columbian niggas outchea tweaking on tv, getting disgusting for the camera',
#  'idiots are told by a man what to wear ',
#  ' holy fuck the hardy boys!!!! wrestlemania',
#  ' join us today on the dc mall for pussy march 2 against evil fascist dictator drumpf. resistance notmypresident imwithh…',
#  ' yoooooo rise n grind. theres a bag out there, get the fuck up and get to it. lets go!!!!!',
#  ' i hate when a song reminds me of someone i give 0 fucks about',
#  'you have always been an idiot 🤣 ',
#  ' jesus, the get out sequel looks fucking terrifying ',
#  "i'm forever thankful for the people that make stupid ass threads of stuff that makes me crack up",
#  'my 21st i wanna be in miami getting so fucked up !!!!!',
#  'im fucking going to san francisco on tuesday!!!!!!!!!!!!',
#  ' had a bad ass night with with my niggas and my girl.    ',
#  " it's beyond fucking cruel that the syrians who will die because of this were doomed regardless of who won our dogshit electio…",
#  ' fucking stop killing us in the name of profits!',
#  " almost 3m views on guala music video!! it's fucking crazy!!!   ",
#  ' if you dont trust your girlfriend or boyfriend why get in a fucking relationship?!!! 😤😤😤',
#  '    hope these evil heartless bastards are found an jailed for benji pls helpfound themupdate',
#  " and once he called me an ungrateful bitch and retarded nigga in an argument. it's how we argued. now… ",
#  'hate bitches that you gotta ask 200 questions to get to what you looking for 😭',
#  "if you can't make a deal with a politician you're a fucking idiot ",
#  " what the hell made you strike syria, &amp; just on suspicion raised by anti-assad sources? you're as bad as your predecessors",
#  '    there are a metric ton of idiots at  ',
#  '   idiots boly to....',
#  "i wanna hate tim tebow so bad but he's the nicest fucking dude in the world.",
#  'klavan, u look like s burglar ffs u stupid estonian cunt',
#  "i hate a person that assumes shyt like come fucking ask me to clarify i ain't gone lie to you dumbass 🖕🏾",
#  ' holy fuck !!! 7 years ago 😩😂👐🏼   ',
#  " you bitches not friends , y'all just hate alike 😝",
�😍😍😍😍😍😍😍😍😍😍😍😍😍😍❤❤❤❤❤❤❤❤❤',
#  'u had shawn michaels, triple h, the rock, cena, even aj styles would have worked, but vince chose 5 move idiot reigns..  wrestlemania',
#  "bone ko na gaske. the idiot stained my certificate with dirty fingers sef. i can't forget him even if i want to. ",
#  " we're so fucking boring.- charles bukowski",
#  ' no donald trump this is all on you!! pack your bags your stupid narcissistic lunatic ass is fired!!',
#  ' her suit was built by bird aliens, you fucking idiotsmen my ass ',
#  ' and idiots spend $8.99 for a bag of skittles. ',
#  "i hate when recipes pop up on my timeline, i'm fucking starving &amp; that does not help",
#  "nah bro that shit was nasty then and it's nasty now 😂 ",
#  ' looks like they are real bad ass fighters...unlike their daddy;-) muahahaha',
#  'im so sick about rick,trusting that bitch talkingdead',
#  'bitch you got 7 dogs you nasty ',
#  'is the apc a bumbling eunuch or a retarded infant? ',
#  " islamic state says u.s. 'being run by an idiot' ",
#  "niggas don't hate yall man, they just don't like you as a person. 😂😂😂",
#  'feel like loading 40 put it to a nigga head, blow out the bad stories',
#  ' lets fucking gooo!!! ',
#  ' a fucking body! ',
#  "just went i thought i was done with this shitty week the alarm system isnt working and i can't leave. oh my god! i hate this place!",
#  "breathtaking.....making money from the presidency and his idiot supporters don't see a problem.... ",
#  "y'all nigga terrible @ washington, district of columbia ",
#  'tap tap tap that ass make it nasty. clap clap clap that ass make it nastytap tap tap that ass make it nasty (_!_)',
#  "we are the hate crew! we stand and we won't fall. we are all for none and none for all.fuck you! we'll fight to th… ",
#  ' im fucking screaming. what he pull out !!!💀 ',
#  ' hole up hole up ..... bitch you this mad all the way in texas ??!!! u dont even go here ',
#  "  hell after benghazi weapons deal gone bad! i don't doubt anything these assholes in dc won't do for power n pockets!",
#  ' she got fucked nd pretended it was april fool.....how stupid could these creatures be',
#  'hate this asshole but he nailed it. ',
#  ' sleep paralysis is the worst fuckin thing to experience',
#  'if governments want to stop refugees, they can, close your fucking borders!!!!!!!!!!!!!!!!!!! ',
#  ' congrats to all the blithering idiots who elected this a**hole: trump just signed away your internet privacy ',
#  'to bad we beat your ass in 2007 giantspride ',
#  "attack on titan s2 episode one's ending was fucked upthat was so brutal",
#  " i'm gonna @ because you are 100000% correct the bulls are going to the finals fuck the cleveland cavaliers! go bulls!'!!!!",
#  '"1. that\'s insulting because i hate monkeys, 2. you\'re a fucking idiot."',
#  ' damn  bares all for  look at that fucking creampie! ',
#  'oh absolutely fucking not! not my ass ',
#  'yall check out my music 💯 let me know if you fucking with it!',
#  'harry fucking dominated that song!!! he has.blown me away!',
#  '  hey.....i think isis is correct!!!  trump...you are ruining our reputation in the world!  you are a fucking idiot!',
#  '  you are a fucking idiot .this is iraq all over again',
#  ' ┏┓ in ┃┃╱╲ this┃╱╱╲╲  house we╱╱╭╮╲╲   fucking hate▔▏┗┛▕▔       cube ent ╱▔▔▔▔▔▔▔▔▔▔╲  ╱╱┏┳┓╭╮┏┳┓ ╲╲ ▔▏┗┻┛┃┃┗┻┛▕▔',
#  ' perhaps an iq test should be a requirement for members of congress. this idiot and sheila jackson lee would flunk',
#  "assad is bad. jihadis also bad &amp; would still be bad w assad gone. assad is an asshole but he didn't create isis.… ",
#  ' im a nasty ass freak when i like you..',
#  'im reading something and this fucking stupid boy is gonna make me cry and im gonna blow up if he does what i think hes gonna do. i s2g. djdk',
#  'hap birth stupid hoe💖💞💃🏻😛  ',
#  'brutal anal orgasm makes her pussy flow ',
#  'if u say baseball is boring than your an ignorant dumbass tbh',
#  ' this looks like a retarded class field trip ',
#  "    you're an idiot",
#  " 'women, huh?' said the cop spoiler alert: he's not just playing bad cop. he's also just an asshole ",
#  ' i hate all you niggas ',
#  'shout-out to wwe partnering with ffxiv tho shits sick',
#  '   out of mouth of someone who worked for obama what a fucking idiot ',
#  'bitch you use to be a fucking gladiator! i dont know why your ginger ass aint look these ppl up b4 you went into bed with them! scandal',
#  ' fucking ganadora!! ',
#  ' (508): i feel like captain morgan put his peg leg up my ass',
#  " sorry darlin, not gonna work. you're in my heart. and that lil sum bitch sees all!!! ",
#  "man i hate when a nigga cock blocking at the function , i'm tryna get laid tonight .!",
#  ' i hate ungrateful bitches 🙄 ',
#  "this isn't a dairy farm simulator??? it's a stupid fucking minigame, come on peta ",
#  " i'm tired of u feminist bitches bc this is just disgusting ",
#  ' yooooo this song is fucking lit!!!!!! repeatttttt ',
#  " yeah the newest one ! it's called hotel o think and it's fucked !",
#  ' damn it hawk those are some quality  calls i wish i could be as bad at my job as  is at his, where did you find this guy',
#  'pull up @ museumbartonight shit will be lit asf!!!!!! infiniteent infinitequeenz',
#  'where the bloody hell is balor?!!!  rawaftermania',
#  ' ew i fucking hate this disgusting tool bag omfg....',
#  ' she is a bloody disgrace she is unfit 2 be primeminister,how the hell do this tory lot sleep at nite se… ',
#  'trumprussia sean spicer is a blithering idiot who will repeat anything trump tells him.',
#  '     something something idiot',
#  " don't fall stupid for these niggas words, let these niggas show u actions",
#  ' what were you doing during the vietnam war? draft-dodging, fucking whores and trying not to get the clap. some hero!',
#  'joanna stern is so fucking annoying please stop doing this',
#  ' que fucked up es 13 reasons why! lpm carajo.',
#  'some of you have horrible characteristics lmaoooo damn',
#  'every side of san antonio bad nigga she banging by the dominions 👀💯',
#  ' anyways then after shinee i went to work the day after aka no sleep (i got rlly fuckin sick at retreat &amp;still recovering rn)',
#  'this how idiots on here operate... i woke up to a hopsin song playing on my tv, i tweet he can rap &amp; from that twee… ',
#  "some might say just do it because that's what men do. i agree but say something lil ugly 😂i'll let that door slam on ya fuckin head",
#  ' the way men think is so fucking stupid',
#  'we just launched missiles at syria?!?! are we going to war?! what the f*ck?!? this idiot has been in office for a couple months and already?',
#  "mcconnell...do you have alzheimer's??? you are an idiot just like trump! ",
#  ' it makes me sick to my stomach to see how bitches dont care about they self respect.',
# ...
#  ' hey tsn stop with the stupid golf and give me my damn leafs for christ sakes',
#  "you won't be around in 2018 ya lyin idiot  ",
#  '      yup .. idiots !! gotta wonder why when the country was going on just…',
#  ' so its an iron man movie that shows some spider-man what a fucking terrible looking movie',
#  ' and you idiots are tweeting obama for help......the man who dropped 50,000 missiles &amp; bombs on iraq and syria every 20 min…',
#  ' worst question to ask a nigga .. " what are we " 😂😂😂😂😂😂😂😂',
#  "except you're fuckin ugly my guy and she ain't got time for you ",
#  ' one reason, pussy. nasty nasty pussy',
#  "i don't trust nobody around my boyfriend period.. he know not to try me , but it's the principal y'all hoes nasty!",
#  '   stop trolling you idiot  !!!',
#  'real shit bro i miss ramdition!!!!! ',
#  'listen to i got bitches freestyle (prod. sleepy eyes) by ugly god np on soundcloud',
#  'who would call u ugly? bad bitch is what they meant — bad bitch jdjsjs thank u sis!  ',
#  '   continue to be an ass about it, and you people are insane if you want to con… ',
#  " what idiot called them nazi's instead of deutschbags",
#  "isis message calls trump 'foolish idiot' ",
#  ' too bad im a puxxy and wont see none of these bc niggas gon be too scared 😂😂 ',
#  'i hate a mice head nigga that want a bitch all to they self but be micen like a mf 😑',
#  ' bad ass kool-cup ',
#  ' this makes me fucking sick!! does it you!?!? ',
#  ' bitches be in twin beds talking about "i hate sleeping alone" bitch u have no choice 😂🙄',
#  ' im a nasty ass freak when i like you..',
#  "     39 mins? it's fucking shrinking! that doesn't ev… ",
#  "voter id has been upheld by the courts, murdering babies is evil, it's not a muslim ban, those are some bullshit co… ",
#  'i dropped my cheesecake on the floor. how fucking tragic.',
#  '  do you want to see andrew neil debunk this &amp; make the person who made this video look like an idiot ?',
#  " i hate when people don't get my sarcasm and i'm out here lookin like a bitch when i'm just making jokes 😒",
#  ' dangal all set to beat 3idiots in taiwan.historic collections',
#  "the worst film i've ever been in my fucking grave.",
#  ' chelsea is the family idiot no skills no smarts just mom and dads money ',
#  " this character is so fuckin' sick ",
#  ' searching fr relevance in any issue making rounds aftr being kicked out of aap. desperate retard compares god to a fiction…',
#  ' ummm do a currency conversion  idiot',
#  'i run around like an idiot with a vibrating flashing noisy gadget in my cleavage and everyone hates me badlyexplainyourjob',
#  ' my niggas is savage, ruthless. we aint goin our classes, we droppin out school',
#  " yeh. but the seasonal waifu spam infiltrates tl's no matter what. was fucking terrible when re:zero was out",
#  ' you an idiot dude... douche bag 😒',
#  ' this idiot is even trolling a trump thread about wounded warriors.literally all he does all day every day is troll trum…',
#  ' simon are you a fucking moron?  yes.... yes is the answer to that question',
#  ' yall niggas want somebody to be yall mom so bad. how ima motivate you and you dont even motivate yourself?! ',
#  " i haven't cried a tear until today - but fuck this week has been awful. just like those days in the schoolground.this fo…",
#  '  dewayne dedmon youf ucking retard',
#  'this is how these idiots will look as fools ',
#  '  yup. i hated the way it ended. fuckin tease',
#  ' i hate a frontin ass person, stay from around me!!! perioddd',
#  '      the idiot list',
#  " i'm tired of u feminist bitches bc this is just disgusting ",
#  ' too bad i cant glo with u too bad i have to stunt on you for life too fucking bad',
#  ' i hate all talk ass people. if you say something do it, if you want something get it',
#  ' yesssss the fucking hardysssss !!!!!!!!!',
#  " isis calls trump an 'idiot' and tells u.s. to await 'bloodbath' in official comments ",
#  " and for all those who don't see what i do with  fucking finish!! aiden onion bag !! millwall lionstv ",
#  ' do u guys ever listen or robots and dodos sitting in cust care? idiots ',
#  " hahah i saw on your snap stories, she's a real bad bitch",
#  " . trump is evil.and if u support him still now—u bet your ass you're evil too.gopbloodmoney trumpleaks tru…",
#  ' oh yes i forgot to mention this to you today!! who the bloody hell is going to replace him?!',
#  'you sayyy you hate me but you stalk my page, you fucking hypocrite ',
#  'i need a bad bitch who keep a hand grenade in her burberry',
#  '  it is a very very fucking bad idea to say terrible lies about your allies. see?',
#  ' annoying ass kids are birth control for me.',
#  'know them niggas lookin so you know they gon hate 😈',
#  "i don't know what's worse: the yooka-laylee rap or the people in the comment section whining about jontron. it's so goddamn pathetic.",
#  " hey i hope you're having the worst day of your life today and then again tomorrow. you are a disgusting piece of shit",
#  ' here in oklahoma we cut funding for everything &amp; wonder why our roads are shitty &amp; kids are stupid ',
#  ' normani did u rest? bad bitches needs to',
#  ' bilic i fucking hate you, watch us lose to swansea and relegation will be imminent',
#  " tweets like yours happen, when you are retarded and your don't know it",
#  "  fox news ? where do they get theirs from? oh that's the fake news trump keeps bitching about! bahhhh!",
#  'send these idiots to venezuela - see how they survive, ',
#  ' how you hate somebody you never even spoke to? bitches be jealous &amp; maaddddddd. ',
#  " i'm stingy as fuck with my food, my man, my friends, basically anything that's mineeeeee!!!!!!!!!!",
#  " mate we don't even know if he even knew her. was fucking horrific.",
#  " ppl so fuckin annoying this is why i don't associate w anyone",
#  "yo u don't even fuckin know about life bro that shits crazy anything could happen gotdamn how tight is that !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!",
#  " regarding today's scoreboard. the 5th of april is a fucking wednesday!!!",
#  'mauro ranallo interrupted the wedding of shane mcmahon with a five star frog splash in winnipeg you idiot',
#  ' i fucking hate my body and myself.',
#  'me too. but not when my shoes are fucking soaked and my feet are freezing!!!!!!!!!!!!! ',
#  'result:   from your idiot employee, you could atleast replace my windshield ',
#  ' horse face hoe stop playing before i show the world yo lil ugly ass',
#  ' how to trick an idiot ',
#  'i hate corny ass niggas who message you asking to join their pyramid skim headasses',
#  'my bitch fucked another nigga that hurt my feelings !',
#  " i need me a lil baby who goin' listennn, because i fucking hate repeating myself",
#  ' 10 is a lot of bad bitches to be in a mansion',
#  'her voice is so fucking annoying ',
#  ' or, hey, maybe retconning captain america into a nazi is bad for sales. ',
#  "i'm heading to bed . @ 1d don't you dare drop a fucking lit info while i'm sleeping ! ",
#  " as soon as y'all post y'all ugly ass kids on ig, i hit that unfollow button",
#  ' bullying is so fucking wrong and disgusting why is it happening i dont understand',
#  'i hate this lmaoooo pisses me off ',
#  ' your litterally just making ecxuses for droping 2 kills in 2 maps ask anyone we dont boot you werent lagging doshit retard',
#  " isis calls trump an 'idiot' and tells u.s. to await 'bloodbath' in official comments ",
#  " idgaf what my shorty wear cause niggas can look buh can't have 🤷🏽\u200d♂️👌🏾not finna stop ha from looking bad asl 🤤",
#  '  michael please notice this im fucking begging !!!  ',
#  "  and i can tell you that's a terrible idea. don't fuckin' do it.",
#  ' jesus, the get out sequel looks fucking terrifying ',
#  " i'm so fucking pissed. shittest thing to do!",
#  ' when all the homies jack off in the bong and u fuckin smoke that shit!!!!!!!!',
#  'that\'s vince steelhammer! and the guy who said "pick up the fucking phone!"',
#  ' hey wassup u bad energy spreading motherfucker',
#  "that's me wanna know why am so mlg and bad ass it's because somebody wanted to roast me but i ended up roasting him… ",
#  'who the fuck would say no to that ring?!?! mercy! wrestlemania',
#  '*takes one snap* &amp; says,"oh my god, i\'m so fuckin ugly" 😂',
#  '    billy bad ass huh?',
#  ' i hate a frontin ass person, stay from around me!!! perioddd',
#  'how bad is that "slut" tattoo on her arse ',
#  ' nigel farage is an idiot brit who should keep his trap shut about america.',
#  '"i don\'t know isn\'t a viable response...intelligence" idiots',
#  ' "i don\'t like him/her because he/she is annoying"; the fucking dumbest reason to not like someone. everyone is annoyin…',
#  'they lied about your evil ass ',
#  ' blame your idiot father for not holding assad accountable. deaths are on him.',
#  'way these bitches hate i hope they get a check for it',
#  '"another day in fucking paradise, fellas!" - things you hear in the hallways of city college😂',
#  " wym where??? i'm nothing like them ugly ass females and i refuse to be compared to one",
#  ...]

# %%
sentences = ['This framework generates embeddings for each input sentence',
    'Sentences are passed as a list of string.', 
    'The quick brown fox jumps over the lazy dog.']
sentence_embeddings = model.encode(t, show_progress_bar = True)

print("Sentence embeddings:")
print(sentence_embeddings)
# Out:
# Batches:   0%|          | 0/1800 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-eca3ce2bad4a> in <module>
#       2     'Sentences are passed as a list of string.',
#       3     'The quick brown fox jumps over the lazy dog.']
# ----> 4 sentence_embeddings = model.encode(t, show_progress_bar = True)
#       5
#       6 print("Sentence embeddings:")
#
# ~\anaconda3\envs\nlp\lib\site-packages\sentence_transformers\SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     192
#     193             with torch.no_grad():
# --> 194                 out_features = self.forward(features)
#     195
#     196                 if output_value == 'token_embeddings':
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\sentence_transformers\models\Transformer.py in forward(self, features)
#      36             trans_features['token_type_ids'] = features['token_type_ids']
#      37
# ---> 38         output_states = self.auto_model(**trans_features, return_dict=False)
#      39         output_tokens = output_states[0]
#      40
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     979             output_attentions=output_attentions,
#     980             output_hidden_states=output_hidden_states,
# --> 981             return_dict=return_dict,
#     982         )
#     983         sequence_output = encoder_outputs[0]
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     573                     encoder_attention_mask,
#     574                     past_key_value,
# --> 575                     output_attentions,
#     576                 )
#     577
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     459             head_mask,
#     460             output_attentions=output_attentions,
# --> 461             past_key_value=self_attn_past_key_value,
#     462         )
#     463         attention_output = self_attention_outputs[0]
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     392             encoder_attention_mask,
#     393             past_key_value,
# --> 394             output_attentions,
#     395         )
#     396         attention_output = self.output(self_outputs[0], hidden_states)
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     307                 attention_scores = attention_scores + relative_position_scores_query + relative_position_scores_key
#     308
# --> 309         attention_scores = attention_scores / math.sqrt(self.attention_head_size)
#     310         if attention_mask is not None:
#     311             # Apply the attention mask is (precomputed for all layers in BertModel forward() function)
#
# RuntimeError: CUDA out of memory. Tried to allocate 368.00 MiB (GPU 0; 6.00 GiB total capacity; 1.50 GiB already allocated; 45.75 MiB free; 2.10 GiB reserved in total by PyTorch)

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# calculate distance between every embedding pair
sim_mat = cosine_similarity(sentence_embeddings, sentence_embeddings)
#df['sim_score'] = sim_mat[sentence_id]
print(sim_mat)
# Out:
# [[0.9999999  0.6773611  0.5380703  ... 0.6322875  0.5764329  0.4508838 ]
#  [0.6773611  1.0000002  0.61836547 ... 0.52597415 0.4757018  0.6055591 ]
#  [0.5380703  0.61836547 0.99999976 ... 0.6413284  0.44478408 0.71698225]
#  ...
#  [0.6322875  0.52597415 0.6413284  ... 1.0000001  0.68636215 0.66588634]
#  [0.5764329  0.4757018  0.44478408 ... 0.68636215 1.         0.4450283 ]
#  [0.4508838  0.6055591  0.71698225 ... 0.66588634 0.4450283  1.0000001 ]]

# %%
#fig, ax = plt.subplots(figsize=(20,20))
#cax = ax.matshow(sim_mat, interpolation='nearest',cmap=plt.get_cmap("PiYG", 7))
#plt.show()

# %%
test = np.array(labels)[ids]
test[380]
# Out:
# 'abusive'

# %%
l
# Out:
# array(['abusive', 'abusive', 'abusive', ..., 'toxic', 'toxic', 'toxic'],
#       dtype='<U12')

# %%
score = {}
for i in range(len(l)):
    x = score.get(l[i])
    if x is None:
        x = []
    x.append(sim_mat[100,i])
    score[l[i]] = x

# %%
for k,v in score.items():
    print(f"{k}:{sum(v)/len(v)}")
# Out:
# abusive:0.548642216246327
# benevolent:0.3639728215106179
# cyberbulling:0.5553497914369254
# hate:0.5021933754611336
# hateful:0.5213420356747899
# identity:0.5573462934108542
# insult:0.5724724596479862
# obscene:0.5619860594533649
# offensive:0.5491760259350905
# profane:0.5379522189084573
# racism:0.4628546318837575
# sexism:0.42895229348049635
# spam:0.3164483376041707
# threat:0.5561771673699802
# toxic:0.5547630333334151

# %%
labs, occ = np.unique(l, return_counts = True)
occ
# Out:
# array([ 4219,  2339,   258,  1264,  1749,  1404,  7872,  8444,   520,
#          757,   140,  3541,  7724,   478, 16872], dtype=int64)

# %%
print(l)
print(labs)
# Out:
# ['abusive' 'abusive' 'abusive' ... 'toxic' 'toxic' 'toxic']
# ['abusive' 'benevolent' 'cyberbulling' 'hate' 'hateful' 'identity'
#  'insult' 'obscene' 'offensive' 'profane' 'racism' 'sexism' 'spam'
#  'threat' 'toxic']

# %%
indices = np.cumsum(occ)
indices = np.insert(indices, 0, 0)
indices
# Out:
# array([    0,  4219,  6558,  6816,  8080,  9829, 11233, 19105, 27549,
#        28069, 28826, 28966, 32507, 40231, 40709, 57581], dtype=int64)

# %%
new_m = np.zeros((len(occ), len(occ)))
for i in range(len(indices)-1):
    for j in range(len(indices)-1):
        x = indices[i]
        y = indices[j]
        x1 = indices[i+1]
        y1 = indices[j+1]
        
        #print(f"{x},{y},{x1},{y1}")
        new_m[i,j] = np.mean(sim_mat[int(x):int(x1), int(y):int(y1)])

# %%
df = pd.DataFrame(new_m, columns = labs, index = labs)
df
# Out:
#                abusive  benevolent  cyberbulling      hate   hateful  \
# abusive       0.486122    0.365396      0.507055  0.456422  0.472566
# benevolent    0.365396    0.563384      0.428881  0.360808  0.362914
# cyberbulling  0.507055    0.428881      0.649109  0.528731  0.517690
# hate          0.456422    0.360808      0.528731  0.494657  0.468746
# hateful       0.472566    0.362914      0.517690  0.468746  0.473822
# identity      0.487023    0.367081      0.536395  0.479045  0.485964
# insult        0.506274    0.371059      0.547650  0.483700  0.496529
# obscene       0.499340    0.368509      0.539736  0.477434  0.488910
# offensive     0.492495    0.369017      0.554633  0.516784  0.501651
# profane       0.478809    0.360881      0.526117  0.486780  0.478144
# racism        0.417236    0.345812      0.460514  0.421078  0.417830
# sexism        0.413629    0.408386      0.460398  0.399930  0.407637
# spam          0.280095    0.302681      0.329796  0.310146  0.282948
# threat        0.498378    0.367877      0.540146  0.486478  0.496661
# toxic         0.495073    0.368205      0.543321  0.479220  0.488143
#
#               identity    insult   obscene  offensive   profane    racism  \
# abusive       0.487023  0.506274  0.499341   0.492495  0.478809  0.417236
# benevolent    0.367081  0.371059  0.368508   0.369017  0.360881  0.345812
# cyberbulling  0.536395  0.547650  0.539736   0.554633  0.526117  0.460514
# hate          0.479044  0.483700  0.477434   0.516784  0.486780  0.421078
# hateful       0.485964  0.496529  0.488911   0.501651  0.478143  0.417830
# identity      0.542316  0.531190  0.522609   0.521322  0.500007  0.438265
# insult        0.531190  0.546737  0.538829   0.525447  0.508638  0.439706
# obscene       0.522609  0.538830  0.532097   0.516431  0.502325  0.435050
# offensive     0.521322  0.525447  0.516431   0.558321  0.520112  0.441586
# profane       0.500007  0.508638  0.502326   0.520112  0.500862  0.429466
# racism        0.438265  0.439706  0.435050   0.441586  0.429466  0.398216
# sexism        0.414459  0.428816  0.425436   0.414319  0.406528  0.379953
# spam          0.288307  0.288112  0.290779   0.300416  0.306727  0.302154
# threat        0.530267  0.542479  0.533925   0.534500  0.504042  0.426893
# toxic         0.518866  0.534066  0.526996   0.516126  0.499410  0.434491
#
#                 sexism      spam    threat     toxic
# abusive       0.413628  0.280094  0.498378  0.495072
# benevolent    0.408386  0.302681  0.367877  0.368206
# cyberbulling  0.460398  0.329796  0.540146  0.543321
# hate          0.399929  0.310146  0.486478  0.479220
# hateful       0.407637  0.282948  0.496661  0.488144
# identity      0.414459  0.288306  0.530267  0.518867
# insult        0.428816  0.288113  0.542479  0.534066
# obscene       0.425436  0.290779  0.533925  0.526995
# offensive     0.414319  0.300416  0.534500  0.516126
# profane       0.406528  0.306727  0.504042  0.499410
# racism        0.379953  0.302154  0.426892  0.434491
# sexism        0.420367  0.286881  0.400926  0.425341
# spam          0.286882  0.348196  0.274337  0.291922
# threat        0.400926  0.274337  0.622606  0.528605
# toxic         0.425341  0.291923  0.528605  0.523586

# %%
fig, ax = plt.subplots(figsize=(20,20))
cax = ax.matshow(df, interpolation='nearest',cmap=plt.get_cmap("PiYG", 30))

for i in range(new_m.shape[0]):
    for j in range(new_m.shape[0]):
        c = new_m[j,i]
        ax.text(i, j, f"{c:.2f}", va='center', ha='center')

fig.colorbar(cax)

ax.set_xticks(np.arange(len(labs)))
ax.set_yticks(np.arange(len(labs)))
ax.set_xticklabels(labs.tolist())
ax.set_yticklabels(labs.tolist())
plt.show()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
mask = np.triu(np.ones_like(new_m), k = 1)
sns.heatmap(df, cmap="YlGnBu", annot=True, mask=mask, ax = ax, vmin=0, vmax=1)
plt.show()

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
torch.zeros(1).cuda()
# Out:
# tensor([0.], device='cuda:0')

# %%
#!pip uninstall -y torch
