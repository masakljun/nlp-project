# %% [markdown]
# # Non-contextual embeddings
# In this notebook we run the code for Word2Vec, Glove, and FastText for words extracted with TF-IDF in the previous notebook. Results of this notebook are not included in the final report.

# %%
import gensim
import gensim.downloader
from sklearn.manifold import TSNE
from sklearn.manifold import MDS
from sklearn.decomposition import PCA
import numpy as np
import tempfile
import imageio
import shutil
import os
from statistics import mean
import pandas as pd 
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer 
from gensim.test.utils import datapath
from gensim.models.fasttext import load_facebook_vectors

from IPython.display import Image
from IPython.display import display
pd.options.display.max_columns = None

import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

# %%
TOP_N = 20
KEYS = { \
   "peopl": set(),
    "white": set(),
    "terror": set(),
    "feminazi": set(),
    "women": set(),
    "sexist": set(),
    "classy": set(),
    "sassy": set(),
    "nasty":set(),
    "stupid": set(),
    "shit": set(),
    "idiot": set(),
    "trump": set(),
    "nigga": set(),
    "giveaway": set(),
    "game": set(),
    "enter": set(),
    "guy": set(),
    "good": set(),
    "gone": set(),
    "world": set(),
    "fuck": set(),
    "little": set(),
    "ass": set(),
    "stupid": set(),
    "bitch": set(),
    "douchebag": set(),
    "die": set(),
    "block":set()
    
}
FIXED_KEYS = list(KEYS.keys())

# %%
lemmatizer = WordNetLemmatizer() 
ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    stem = ps.stem(key)
    KEYS[key].add(lemma)
    KEYS[key].add(stem)
    KEYS[key].add(key)
KEYS
# Out:
# {'peopl': {'peopl'},
#  'white': {'white'},
#  'terror': {'terror'},
#  'feminazi': {'feminazi'},
#  'women': {'woman', 'women'},
#  'sexist': {'sexist'},
#  'classy': {'classi', 'classy'},
#  'sassy': {'sassi', 'sassy'},
#  'nasty': {'nasti', 'nasty'},
#  'stupid': {'stupid'},
#  'shit': {'shit'},
#  'idiot': {'idiot'},
#  'trump': {'trump'},
#  'nigga': {'nigga'},
#  'giveaway': {'giveaway'},
#  'game': {'game'},
#  'enter': {'enter'},
#  'guy': {'guy'},
#  'good': {'good'},
#  'gone': {'gone'},
#  'world': {'world'},
#  'fuck': {'fuck'},
#  'little': {'littl', 'little'},
#  'ass': {'as', 'ass'},
#  'bitch': {'bitch'},
#  'douchebag': {'douchebag'},
#  'die': {'die'},
#  'block': {'block'}}

# %%
def same_word(similar_word, ommit_words):
    similar_word = similar_word.replace("_", " ").replace("-", " ").lower()
    
    if similar_word in ommit_words:
        print(f"{ommit_words} -- {similar_word}")
        return True
    
    for ommit_word in ommit_words:
        if ommit_word in similar_word:
            print(f"{ommit_words} -- {similar_word}")
            return True
        
    return False

# %%
def getSimilarWords(model_gn):
    embedding_clusters = []
    word_clusters = []
    for key in FIXED_KEYS:
        ommit_words = KEYS[key]
        embeddings = []
        words = []
        for similar_word, _ in model_gn.most_similar(key, topn=TOP_N * 3):
            if not same_word(similar_word, ommit_words):
                words.append(similar_word)
                embeddings.append(model_gn[similar_word])
                
        if len(words) < TOP_N or len(embeddings) < TOP_N:
            print("ERROR")
            print(key)
            
        words = words[:TOP_N]
        embeddings = embeddings[:TOP_N]
        
        embedding_clusters.append(embeddings)
        word_clusters.append(words)
        
    return (word_clusters, embedding_clusters)

# %%
def displayDF(word_clusters):
    df = pd.DataFrame(dict(zip(FIXED_KEYS, word_clusters)))  
    display(df)

# %%
def plot_similar_words(title, labels, embedding_clusters, word_clusters, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=0.7, label=label)
        for i, word in enumerate(words):              
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=8)
        plt.annotate(label.upper(), alpha=1.0, xy=(mean(x), mean(y)), xytext=(0, 0),
            textcoords='offset points', ha='center', va='center', size=15)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(False)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
def plotTSNE(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    print(embedding_clusters.shape)
    n, m, k = embedding_clusters.shape
    model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotMDS(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = MDS(n_components=2, max_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
def plotPCA(title, word_clusters, embedding_clusters, filename = None):
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = PCA(n_components=2, random_state = 32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, FIXED_KEYS, embeddings_en_2d, word_clusters, filename)

# %%
model_gn = gensim.downloader.load('word2vec-google-news-300')

# %%
word_clusters_a, embedding_clusters = getSimilarWords(model_gn)
# Out:
# {'peopl'} -- people.i
# {'peopl'} -- people
# {'white'} -- whites
# {'terror'} -- terrorism
# {'terror'} -- terrorist
# {'terror'} -- terrorists
# {'terror'} -- terrorist attacks
# {'terror'} -- terror
# {'terror'} -- terrorist
# {'terror'} -- terrorism
# {'terror'} -- counter terrorism
# {'terror'} -- terror plots
# {'terror'} -- counterterrorism
# {'terror'} -- antiterrorism
# {'terror'} -- antiterror
# {'terror'} -- terror suspects
# {'terror'} -- homegrown terrorists
# {'feminazi'} -- feminazis
# {'women', 'woman'} -- women
# {'women', 'woman'} -- womens
# {'women', 'woman'} -- transwomen
# {'women', 'woman'} -- women
# {'women', 'woman'} -- woman
# {'women', 'woman'} -- womens
# {'women', 'woman'} -- women.the
# {'women', 'woman'} -- women's
# {'women', 'woman'} -- womenfolk
# {'women', 'woman'} -- women's
# {'women', 'woman'} -- businesswomen
# {'women', 'woman'} -- womenâ € ™
# {'women', 'woman'} -- workingwomen
# {'sexist'} -- blatantly sexist
# {'sexist'} -- racist sexist
# {'sexist'} -- sexist
# {'sexist'} -- sexists
# {'sexist'} -- overtly sexist
# {'sexist'} -- sexist remark
# {'sexist'} -- sexist jokes
# {'sexist'} -- sexist racist
# {'sexist'} -- sexist slur
# {'sexist'} -- sexist homophobic
# {'classy', 'classi'} -- classy
# {'classy', 'classi'} -- classier
# {'classy', 'classi'} -- classiest
# {'classy', 'classi'} -- classically elegant
# {'classy', 'classi'} -- classiness
# {'classy', 'classi'} -- unclassy
# {'classy', 'classi'} -- classily
# {'sassi', 'sassy'} -- sassiness
# {'sassi', 'sassy'} -- sexy sassy
# {'sassi', 'sassy'} -- sassy sexy
# {'nasti', 'nasty'} -- nastiest
# {'nasti', 'nasty'} -- nastier
# {'nasti', 'nasty'} -- downright nasty
# {'nasti', 'nasty'} -- nasty
# {'nasti', 'nasty'} -- nastiness
# {'stupid'} -- stupid stupid
# {'stupid'} -- stupidest
# {'stupid'} -- stupid
# {'stupid'} -- monumentally stupid
# {'stupid'} -- stupid
# {'shit'} -- bullshit
# {'shit'} -- fucking shit
# {'shit'} -- shite
# {'shit'} -- shitty
# {'shit'} -- shit
# {'idiot'} -- idiots
# {'idiot'} -- blithering idiot
# {'idiot'} -- idiotic
# {'idiot'} -- idiot
# {'trump'} -- trumps
# {'trump'} -- trumping
# {'trump'} -- trumped
# {'trump'} -- trump card
# {'trump'} -- trumping
# {'nigga'} -- niggas
# {'nigga'} -- niggas
# {'nigga'} -- nigga
# {'nigga'} -- niggaz
# {'nigga'} -- ass nigga
# {'giveaway'} -- giveaways
# {'giveaway'} -- giveaway
# {'giveaway'} -- giveaways
# {'giveaway'} -- prize giveaways
# {'giveaway'} -- giveaway contest
# {'giveaway'} -- promotional giveaways
# {'giveaway'} -- giveaway sweepstakes
# {'game'} -- games
# {'game'} -- agame
# {'game'} -- ballgame
# {'game'} -- thegame
# {'game'} -- game
# {'game'} -- fourgame
# {'game'} -- game'sa
# {'game'} -- threegame
# {'game'} -- game.the
# {'game'} -- game1
# {'game'} -- fivegame
# {'game'} -- game2
# {'enter'} -- entering
# {'enter'} -- entered
# {'enter'} -- reenter
# {'enter'} -- enters
# {'enter'} -- entering
# {'enter'} -- enter
# {'enter'} -- reentering
# {'enter'} -- entered
# {'enter'} -- reentered
# {'guy'} -- guys
# {'guy'} -- guy'sa
# {'guy'} -- rah rah guy
# {'guy'} -- sinkerball guy
# {'good'} -- good
# {'good'} -- agood
# {'world'} -- theworld
# {'world'} -- worldâ € ™
# {'world'} -- worldwide
# {'world'} -- worlds
# {'world'} -- worldís
# {'world'} -- world
# {'world'} -- worldâ
# {'world'} -- world.â €
# {'world'} -- world's
# {'world'} -- world.the
# {'world'} -- world
# {'world'} -- world.i
# {'fuck'} -- fucking
# {'fuck'} -- fucked
# {'fuck'} -- fuckin
# {'fuck'} -- fuck
# {'fuck'} -- fucks
# {'fuck'} -- motherfucker
# {'fuck'} -- mother fucker
# {'fuck'} -- motherfuckers
# {'fuck'} -- fucker
# {'fuck'} -- fucken
# {'fuck'} -- wanna fuck
# {'little', 'littl'} -- littler
# {'little', 'littl'} -- alittle
# {'as', 'ass'} -- asses
# {'as', 'ass'} -- yo ass
# {'as', 'ass'} -- asshole
# {'as', 'ass'} -- dumbass
# {'bitch'} -- bitches
# {'bitch'} -- bitch bitch
# {'bitch'} -- fucking bitch
# {'bitch'} -- bitch whore
# {'bitch'} -- bitch ass
# {'bitch'} -- psycho bitch
# {'douchebag'} -- douchebags
# {'die'} -- dies
# {'die'} -- die prematurely
# {'die'} -- died
# {'die'} -- die
# {'die'} -- dieing
# {'die'} -- conjoined twin dies
# {'block'} -- blocks
# {'block'} -- blocking
# {'block'} -- blocked

# %%
displayDF(word_clusters_a)
# Out:
#         peopl                          white               terror  \
# 0        peop                          black             al_Qaeda
# 1         ppl                           blue             Al_Qaeda
# 2      peopel                          brown            al_Qa'ida
# 3       peple                        colored             al_Qaida
# 4      poeple                   wrote_Newitz                Qaeda
# 5   nigerians                           gray   Islamic_extremists
# 6       some1                   browns_grays               jihadi
# 7     peo_ple                    blues_grays            al_Qa'eda
# 8       peole                   grays_browns             jihadist
# 9       u_ppl  gorgeously_photographed_black           terrrorism
# 10        peo        Responded_Letterman_How              alQaeda
# 11       u_hv                            red              terrror
# 12      ppl_r                   grays_blacks  Islamist_extremists
# 13     pepole                   blacks_grays            Al_Qa'ida
# 14      pople                crypt_inscribed            jihadists
# 15      peope                  browns_beiges             Al_Qaida
# 16      eople                         yellow    Islamist_militant
# 17       u're    transporting_petrochemicals           extremists
# 18   iranians               burgundy_colored    Islamic_extremist
# 19     ......                         purple            al_Quaeda
#
#                feminazi                     women                 sexist  \
# 0          commie_pinko                       men           misogynistic
# 1              whackjob                     girls                 sexism
# 2          women_libber                   females              demeaning
# 3   male_chauvinist_pig                   mothers                 racist
# 4             nerd_geek                    ladies             misogynist
# 5        chauvinist_pig                  husbands                 vulgar
# 6                harpie                       Men         blatant_sexism
# 7        Andrea_Dworkin                    female                 ageist
# 8               libtard         male_counterparts      objectifies_women
# 9             feminists             teenage_girls  politically_incorrect
# 10              hannity               wear_burkas                bigoted
# 11          bitch_bitch                  lesbians             homophobic
# 12             feminist                 feminists         overtly_sexual
# 13                lesbo                   Latinas               misogyny
# 14               wigger          widows_divorcees           chauvinistic
# 15           douche_bag                     males             unladylike
# 16      bigot_homophobe             undergone_FGM             derogatory
# 17            homophobe    sexual_objectification     racially_demeaning
# 18            femi_nazi                      mens   racially_insensitive
# 19         pinko_commie  undergone_hysterectomies           stereotyping
#
#            classy           sassy       nasty             stupid       shit  \
# 0         stylish          spunky        ugly               dumb     sh_*_t
# 1         elegant            sass     vicious              silly       crap
# 2          lovely          brassy  unpleasant            idiotic    fucking
# 3        tasteful            sexy        vile            foolish       sh_t
# 4         Stylish           perky    spiteful         ridiculous     fuckin
# 5          flashy           vampy         bad          dumb_dumb      sh_**
# 6            nice          bitchy      bitter            moronic       fuck
# 7        fabulous           ditzy      wicked             idiots  f_*_cking
# 8        gorgeous          sexpot    horrible  childish_immature     y'know
# 9           sleek           saucy    viscious               daft       shyt
# 10      brilliant           witty  hellacious              idiot    goddamn
# 11          gutsy       vivacious       scary            asinine     f_*_ck
# 12   eye_catching            foxy      snarly              moron        ass
# 13         superb           kicky    terrible           ignorant       **_t
# 14  scintillating          sultry    unsavory              niave   f_**_kin
# 15      sparkling           ditsy       dirty         rediculous     bullsh
# 16       elegance         girlish     hideous            dumbass       damn
# 17      beautiful       kittenish     caustic      unintelligent    friggin
# 18       splendid          flirty  disgusting              crazy       sh_*
# 19         snazzy  Southern_belle       yucky           dumb_ass       dude
#
#          idiot          trump           nigga                   giveaway  \
# 0        moron      supersede         n_*_gga                 give_aways
# 1      asshole      supercede           ni_**                   giveways
# 2     imbecile        prevail        n_*_ggas                     raffle
# 3      jackass       outweigh           homie                    giveway
# 4      dumbass        trample           kanye                sweepstakes
# 5         dolt     overshadow  motherf_*_cker                    freebie
# 6       stupid        dictate           **_ga                     Raffle
# 7      buffoon  reign_supreme          sh_*_t                  Give_Away
# 8       asshat         negate          brotha             Scavenger_hunt
# 9    ignoramus     overridden           jay_z             Festive_Frenzy
# 10        twit          usurp       lil_wayne                     prizes
# 11    arsehole       undercut          nizzle  Halloween_Costume_Contest
# 12      nitwit        outlast          rappin                 goodie_bag
# 13   douchebag      overwhelm    motherfucker              raffle_prizes
# 14      effing     supersedes           sayin                    coozies
# 15        bozo        becloud           Jeezy                  Foodstock
# 16     dipshit         spades           tryin      Raffle_prizes_include
# 17    assclown       diminish         brothas        drawstring_backpack
# 18  nincompoop         ignore           *_gga                Goodie_bags
# 19  douche_bag     supercedes          f_*_ck            raffle_drawings
#
#             game            enter                         guy         good  \
# 0           play            entry                        dude        great
# 1          match      participate                         kid          bad
# 2        matchup            leave                    somebody     terrific
# 3         opener             join                       fella       decent
# 4        matches         register                       he'sa         nice
# 5     tournament               go                      kidder    excellent
# 6        playing       particpate                       bloke    fantastic
# 7         league           engage                     Mike'sa       better
# 8     scrimmages             send        involuntarily_yawned        solid
# 9      scrimmage          partake                      kid'sa        lousy
# 10    postseason          exiting                     Matt'sa    wonderful
# 11      playoffs           enroll                     someone     terrible
# 12           gme       infiltrate            ROGER_MAYWEATHER        tough
# 13        season    dive_headlong                      schmoe         best
# 14       players          proceed          outworks_everybody      alright
# 15      matchups           submit                     anybody      perfect
# 16  doubleheader  plunge_headlong  Vincent_Lecavalier_Stamkos       strong
# 17          gmae    toparticipate                Whaddya_mean  pretty_darn
# 18     scorefest   dive_headfirst                   Laughing.       really
# 19        played           exited                     schmuck        happy
#
#            gone                     world       fuck         little  \
# 0          went                     globe     f_*_ck            bit
# 1            go                   country     f_**_k           much
# 2          goes                 continent       shit        wee_bit
# 3        fallen                    nation      f_***          litte
# 4          come                    global       f_ck  everything'sa
# 5        gotten             United_States      f_---            lot
# 6          done                  globally     y'know          maybe
# 7         moved                   America     sh_*_t            tad
# 8         going                    Europe    goddamn          litle
# 9   disappeared                    planet  f_*_cking        smidgen
# 10        crept        western_hemisphere  f_**_king           just
# 11       coming               Middle_East   f_***_ed      teeny_bit
# 12        risen                 countries  f_***_ing           some
# 13       turned                continents    asshole           kind
# 14     vanished                     worls   f_****_n  Everything'sa
# 15       stayed        Western_Hemisphere   f_**_kin      litle_bit
# 16      drifted                      worl    af_**_k         liitle
# 17         been             Unites_States     af_***          lttle
# 18     ventured                     wolrd     bullsh          scant
# 19       gotton  Rohullah_Nikpai_defeated    f_*_cks         smidge
#
#                ass          bitch   douchebag  \
# 0             butt        b_*_tch  douche_bag
# 1              azz        ab_****      douche
# 2             shit       ab_*_tch     asshole
# 3             dick         b_****       moron
# 4            hiney          whore      asshat
# 5             dude        b_**_ch     dumbass
# 6           d_*_ck       ab_**_ch     jackass
# 7             nads        bastard        dick
# 8            **_es        asshole    assclown
# 9           sh_*_t     whore_slut        twit
# 10         fucking  motherf_*****     scumbag
# 11          tuchus          ***_h        dude
# 12    motherfucker          b_tch    dickhead
# 13        patootie           cunt        twat
# 14       f_*_cking         biatch   famewhore
# 15          heinie      whine_nag       skank
# 16           fanny           slut      biotch
# 17   mother_fucker       ab_***_h        bozo
# 18            fuck      f_***_ing       idiot
# 19  motherf_*_cker         biotch    assholes
#
#                                    die                    block
# 0                               perish              Exume_tried
# 1                                dying           Kedvale_Avenue
# 2                      oil_Cvitanovich       Terroristic_threat
# 3                                 kill             Hoyne_Avenue
# 4                               starve            Goguac_Street
# 5                              succumb          Briarwood_Drive
# 6                      Fatalistic_kids            Boxwood_Drive
# 7                               suffer             Avers_Avenue
# 8                                death           Woodale_Avenue
# 9                leaving_wispy_strands  South_Telshor_Boulevard
# 10                       Do_Thi_Phuong           Hartrey_Avenue
# 11                                dead           Westline_Drive
# 12                              killed            Karlov_Avenue
# 13                      commit_suicide  burglar_ransacked_house
# 14                              deaths            Kolmar_Avenue
# 15  maybe_accelerated_artherosclerosis            Raguet_Street
# 16                    dying_needlessly       Attempted_burglary
# 17            ZDNet_Download_Datenbank           Basswood_Drive
# 18                          starvation          Montgall_Avenue
# 19                               drown  Walnut_Manor_Apartments

# %%
plotTSNE("Similar words - Word2Vec [t-SNE]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - t-SNE.png")
# Out:
# (28, 20, 300)

# %%
plotMDS("Similar words - Word2Vec [MDS]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - MDS.png")

# %%
plotPCA("Similar words - Word2Vec [PCA]", word_clusters_a, embedding_clusters, "SimilarWords - word2vec - PCA.png")

# %% [markdown]
# ### Clustering

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %% [markdown]
# ### KMeans

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

range_clusters = list(range(2,10))
avg = []
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    avg.append(silhouette_avg)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")
# Out:
# 2 clusters - silhouette: 0.4043654501438141
# 3 clusters - silhouette: 0.324262410402298
# 4 clusters - silhouette: 0.2959015965461731
# 5 clusters - silhouette: 0.29699522256851196
# 6 clusters - silhouette: 0.2891490161418915
# 7 clusters - silhouette: 0.28251293301582336
# 8 clusters - silhouette: 0.2524334192276001
# 9 clusters - silhouette: 0.2693548798561096

# %%
plt.plot(range_clusters, avg)

# %%
num_clusters = 5
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
# Out:
# Wall time: 31 ms
# Clusters: [1, 2, 0, 1, 2, 2, 3, 2, 3, 1, 1, 1, 0, 1, 4, 4, 0, 1, 3, 0, 0, 1, 3, 1, 1, 1, 0, 4]

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")
# Out:
# Cluster 0: ['terror' 'trump' 'enter' 'gone' 'world' 'die']
# Cluster 1: ['peopl' 'feminazi' 'stupid' 'shit' 'idiot' 'nigga' 'guy' 'fuck' 'ass'
#  'bitch' 'douchebag']
# Cluster 2: ['white' 'women' 'sexist' 'sassy']
# Cluster 3: ['classy' 'nasty' 'good' 'little']
# Cluster 4: ['giveaway' 'game' 'block']

# %%
### Hierarhical clustering

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()

# %% [markdown]
# ## glove

# %%
# stran dala: douchebag, feminazi

# %%
TOP_N = 20
KEYS = { \
   "people": set(),
    "white": set(),
    "terror": set(),
    "women": set(),
    "sexist": set(),
    "classy": set(),
    "sassy": set(),
    "nasty":set(),
    "stupid": set(),
    "shit": set(),
    "idiot": set(),
    "trump": set(),
    "nigga": set(),
    "giveaway": set(),
    "game": set(),
    "enter": set(),
    "guy": set(),
    "good": set(),
    "gone": set(),
    "world": set(),
    "fuck": set(),
    "little": set(),
    "ass": set(),
    "stupid": set(),
    "bitch": set(),
    "die": set(),
    "block":set()
    
}
FIXED_KEYS = list(KEYS.keys())

lemmatizer = WordNetLemmatizer() 
ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    stem = ps.stem(key)
    KEYS[key].add(lemma)
    KEYS[key].add(stem)
    KEYS[key].add(key)
KEYS
# Out:
# {'people': {'peopl', 'people'},
#  'white': {'white'},
#  'terror': {'terror'},
#  'women': {'woman', 'women'},
#  'sexist': {'sexist'},
#  'classy': {'classi', 'classy'},
#  'sassy': {'sassi', 'sassy'},
#  'nasty': {'nasti', 'nasty'},
#  'stupid': {'stupid'},
#  'shit': {'shit'},
#  'idiot': {'idiot'},
#  'trump': {'trump'},
#  'nigga': {'nigga'},
#  'giveaway': {'giveaway'},
#  'game': {'game'},
#  'enter': {'enter'},
#  'guy': {'guy'},
#  'good': {'good'},
#  'gone': {'gone'},
#  'world': {'world'},
#  'fuck': {'fuck'},
#  'little': {'littl', 'little'},
#  'ass': {'as', 'ass'},
#  'bitch': {'bitch'},
#  'die': {'die'},
#  'block': {'block'}}

# %%
model_gn = gensim.downloader.load('glove-wiki-gigaword-300')

# %%
word_clusters, embedding_clusters = getSimilarWords(model_gn)
# Out:
# {'white'} -- whites
# {'terror'} -- terrorist
# {'terror'} -- terrorism
# {'terror'} -- terrorists
# {'terror'} -- counterterrorism
# {'women', 'woman'} -- woman
# {'nasti', 'nasty'} -- nastier
# {'shit'} -- bullshit
# {'idiot'} -- idiots
# {'idiot'} -- idiotic
# {'trump'} -- trumps
# {'nigga'} -- niggas
# {'giveaway'} -- giveaways
# {'game'} -- games
# {'enter'} -- entering
# {'enter'} -- entered
# {'enter'} -- enters
# {'guy'} -- guys
# {'world'} -- worlds
# {'world'} -- worldwide
# {'fuck'} -- fucking
# {'fuck'} -- fucked
# {'fuck'} -- motherfucker
# {'as', 'ass'} -- asses
# {'bitch'} -- bitchy
# {'die'} -- died
# {'die'} -- dies
# {'block'} -- blocks
# {'block'} -- blocking
# {'block'} -- blocked

# %%
displayDF(word_clusters)
# Out:
#        people    white      terror      women         sexist         classy  \
# 0      others    black       qaeda        men     homophobic        stylish
# 1       those      red       qaida      girls         racist        elegant
# 2       least     blue     attacks     female     misogynist       tasteful
# 3        many    house  extremists       male   misogynistic           sexy
# 4        some    brown    suspects    mothers      demeaning          gutsy
# 5         all   yellow       osama   athletes        bigoted         flashy
# 6        them     pink    bombings        she  disrespectful       charming
# 7   thousands  colored   extremist      young    insensitive    wonderfully
# 8    hundreds     dark  mastermind   children  condescending  unpretentious
# 9       there     bush    plotting     people    disparaging          sleek
# 10       just     gray     threats     ladies         vulgar      glamorous
# 11       more  clinton   suspected        her     derogatory      supremely
# 12       they    green   extremism        who   chauvinistic     personable
# 13       than  wearing    militant  americans        hateful           nice
# 14   citizens   bright      threat        sex  paternalistic   delightfully
# 15       know    color     bombing      world    stereotypes       elegance
# 16  residents   purple       laden  teenagers    patronizing         lovely
# 17   families       or   militants     gender   hypocritical          suave
# 18       have    obama     suspect       they     stereotype     unassuming
# 19        say    aides        9/11      those         sexism     delightful
#
#            sassy       nasty         stupid         shit       idiot  \
# 0         brassy        ugly          silly      fucking        fool
# 1         spunky     vicious           dumb         crap    imbecile
# 2           sexy     brutish        foolish         fuck  blithering
# 3          perky       messy     ridiculous         suht       moron
# 4          saucy  unpleasant        idiotic       'cause        slob
# 5         cheeky         bad          crazy        gonna      savant
# 6     streetwise      bitter       ignorant        bitch    babbling
# 7      vivacious       stuff     disgusting        kinda      stupid
# 8   wisecracking        rude  irresponsible         damn     fucking
# 9         bitchy       scary          wrong  wannasathit     bastard
# 10     sarcastic    annoying          naive         wahn       klutz
# 11        sultry      pretty     outrageous        bleep     buffoon
# 12      sardonic       silly       arrogant           ’m     deluded
# 13         witty    bruising           cute          n’t       fools
# 14     sprightly   downright        mistake    expletive   hypocrite
# 15        feisty  disgusting          awful          ’re    nonsense
# 16        flirty      stupid           joke          ass    arrogant
# 17         funky    terrible          funny     chitchai    clueless
# 18       soulful   surprises         absurd        gotta    drooling
# 19       raunchy       awful       pathetic          hey   scoundrel
#
#           trump         nigga     giveaway        game        enter  \
# 0         ivana         jigga       raffle        play        entry
# 1       melania         bitch   bobblehead     players        allow
# 2        casino          nyet     takeaway      player   permission
# 3          nows           b/w    give-away       match         able
# 4        knauss  motherfucker     clunkers     playing         into
# 5        hilton          aint   boondoggle     scoring         join
# 6        ivanka        holdin      handout      played      allowed
# 7       resorts         allâh  promotional      season  participate
# 8          wynn          fuck  discounting    playoffs       permit
# 9       casinos         amrut      subsidy     playoff         must
# 10        mahal        nothin     vouchers  postseason         seek
# 11          taj        leavin      coupons     matches    permitted
# 12       donald          pono         gift       score        leave
# 13          mih     so-and-so      goodies    football           to
# 14    developer        gettin      freebie        team       cannot
# 15       marina        nigger      rebates    baseball        would
# 16        condo       asshole          toy  tournament        reach
# 17        vegas        briber      whopper       teams       obtain
# 18       westin    thumbtacks      10-cent       first           go
# 19  condominium    jitterbugs      voucher         nba         will
#
#           guy       good        gone          world       fuck     little  \
# 0       thing     better          go           ever       shit        bit
# 1         kid     really       going           time      wanna       much
# 2    somebody     always        went         global      bitch        lot
# 3        nice        you        just          event  expletive        too
# 4      really       well        goes  international      gonna    nothing
# 5       stuff  excellent        come       champion        'em       even
# 6          'm       very         've        america      bleep       just
# 7   everybody     things     nothing          first        ass        few
# 8       knows      think      anyway  championships       crap        but
# 9         man        way       maybe         events     gettin       kind
# 10        dad       sure         but            all       yeah         so
# 11      maybe      thing          we             in         ?!     enough
# 12       kind         so     nowhere        country      outta  something
# 13     pretty        n't           ?         europe      gotta        get
# 14      likes         we        back           here         y'       what
# 15         'd        lot      coming            one          !     things
# 16       know        get         n't         nation       damn     really
# 17        you        but  everything        nations     'cause       good
# 18     nobody      going          so            the      punks     though
# 19      think       kind        away         second        hey   actually
#
#           ass    bitch      die      block
# 0        arse     slut    dying   building
# 1       bitch  fucking     dead       move
# 2        fuck  bastard    death    prevent
# 3        shit    whore     kill     access
# 4     fucking    mommy   perish       stop
# 5      messed    daddy      der      house
# 6        butt     fuck     sick      allow
# 7       momma     shit      und       push
# 8   expletive      ass     welt      floor
# 9        dumb      hey   deaths   proposed
# 10     stupid   nigger    hards      which
# 11    screwed    gonna   suffer     houses
# 12      crazy    smack   starve       main
# 13      gonna    puppy        !   designed
# 14       kick   skinny        ?       plan
# 15         ox     mama   people  buildings
# 16     cheeky   'cause  survive     effort
# 17      shins       'n     wait   addition
# 18      daddy    wanna   others   intended
# 19        'em    crazy   killed   concrete

# %%
plotTSNE("Similar words - Glove [t-SNE]", word_clusters, embedding_clusters, "SimilarWords - Glove - t-SNE.png")
# Out:
# (26, 20, 300)

# %%
plotMDS("Similar words - Glove [MDS]", word_clusters, embedding_clusters, "SimilarWords - Glove - MDS.png")

# %%
plotPCA("Similar words - Glove [PCA]", word_clusters, embedding_clusters, "SimilarWords - Glove - PCA.png")

# %%
## Clustering

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %%
### KMeans

# %%
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))
range_clusters = list(range(2,10))
avg = []
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    avg.append(silhouette_avg)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")
# Out:
# 2 clusters - silhouette: 0.4910459816455841
# 3 clusters - silhouette: 0.412577748298645
# 4 clusters - silhouette: 0.3211785554885864
# 5 clusters - silhouette: 0.3152727782726288
# 6 clusters - silhouette: 0.37870651483535767
# 7 clusters - silhouette: 0.3752214014530182
# 8 clusters - silhouette: 0.3468892276287079
# 9 clusters - silhouette: 0.3687278926372528

# %%
plt.plot(range_clusters, avg)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
# Out:
# Text(0, 0.5, 'Silhouette score')

# %%
num_clusters = 6
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
# Out:
# Wall time: 40.5 ms
# Clusters: [2, 2, 2, 2, 5, 5, 5, 4, 4, 1, 5, 3, 5, 3, 2, 2, 0, 0, 0, 2, 1, 0, 1, 1, 0, 2]

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")
# Out:
# Cluster 0: ['guy' 'good' 'gone' 'little' 'die']
# Cluster 1: ['shit' 'fuck' 'ass' 'bitch']
# Cluster 2: ['people' 'white' 'terror' 'women' 'game' 'enter' 'world' 'block']
# Cluster 3: ['trump' 'giveaway']
# Cluster 4: ['nasty' 'stupid']
# Cluster 5: ['sexist' 'classy' 'sassy' 'idiot' 'nigga']

# %%
### Hierarchical

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()

# %% [markdown]
# ## fasttext

# %%
# Run first time only to download model
#import fasttext.util
#fasttext.util.download_model('en', if_exists='ignore')  # English
#ft = fasttext.load_model('cc.en.300.bin')

# %%
model_gn = load_facebook_vectors("cc.en.300.bin")

# %%
TOP_N = 30
KEYS = { \
   "people": set(),
    "white": set(),
    "terror": set(),
#    "women": set(),
    "sexist": set(),
    "classy": set(),
    "sassy": set(),
    "nasty":set(),
    "stupid": set(),
    "shit": set(),
    "idiot": set(),
    "trump": set(),
    "nigga": set(),
    "giveaway": set(),
#    "game": set(),
    "enter": set(),
    "guy": set(),
    "good": set(),
    "gone": set(),
#    "world": set(),
    "fuck": set(),
    "little": set(),
    "ass": set(),
    "stupid": set(),
    "bitch": set(),
    "die": set(),
#    "block":set()
    
}
FIXED_KEYS = list(KEYS.keys())

lemmatizer = WordNetLemmatizer() 
ps = PorterStemmer() 


for key in KEYS.keys():
    lemma = lemmatizer.lemmatize(key)
    stem = ps.stem(key)
    KEYS[key].add(lemma)
    KEYS[key].add(stem)
    KEYS[key].add(key)
KEYS
# Out:
# {'people': {'peopl', 'people'},
#  'white': {'white'},
#  'terror': {'terror'},
#  'sexist': {'sexist'},
#  'classy': {'classi', 'classy'},
#  'sassy': {'sassi', 'sassy'},
#  'nasty': {'nasti', 'nasty'},
#  'stupid': {'stupid'},
#  'shit': {'shit'},
#  'idiot': {'idiot'},
#  'trump': {'trump'},
#  'nigga': {'nigga'},
#  'giveaway': {'giveaway'},
#  'enter': {'enter'},
#  'guy': {'guy'},
#  'good': {'good'},
#  'gone': {'gone'},
#  'fuck': {'fuck'},
#  'little': {'littl', 'little'},
#  'ass': {'as', 'ass'},
#  'bitch': {'bitch'},
#  'die': {'die'}}

# %%
word_clusters, embedding_clusters = getSimilarWords(model_gn)
# Out:
# {'people', 'peopl'} -- people.people
# {'people', 'peopl'} -- people.those
# {'people', 'peopl'} -- people.some
# {'people', 'peopl'} -- people.many
# {'people', 'peopl'} -- people  people
# {'people', 'peopl'} -- people
# {'people', 'peopl'} -- people.if
# {'people', 'peopl'} -- people.i
# {'people', 'peopl'} -- people.they
# {'people', 'peopl'} -- people.so
# {'people', 'peopl'} -- peoplee
# {'people', 'peopl'} -- peoplel
# {'people', 'peopl'} -- people.but
# {'people', 'peopl'} -- people  they
# {'people', 'peopl'} -- peoplen
# {'people', 'peopl'} -- people.when
# {'people', 'peopl'} -- peoples
# {'people', 'peopl'} -- people  including
# {'people', 'peopl'} -- people  who
# {'people', 'peopl'} -- people people
# {'people', 'peopl'} -- people.most
# {'people', 'peopl'} -- people.you
# {'people', 'peopl'} -- people.because
# {'people', 'peopl'} -- people.now
# {'people', 'peopl'} -- peopld
# {'people', 'peopl'} -- peopler
# {'people', 'peopl'} -- people.one
# {'people', 'peopl'} -- ppeople
# {'people', 'peopl'} -- people  and
# {'people', 'peopl'} -- people.it
# {'people', 'peopl'} -- people.and
# {'people', 'peopl'} -- people.all
# {'people', 'peopl'} -- people.while
# {'people', 'peopl'} -- people.then
# {'people', 'peopl'} -- them.people
# {'people', 'peopl'} -- people.we
# {'people', 'peopl'} -- people.why
# {'people', 'peopl'} -- people  or
# {'people', 'peopl'} -- people.however
# {'people', 'peopl'} -- people.as
# {'people', 'peopl'} -- people.what
# {'people', 'peopl'} -- people.sometimes
# {'people', 'peopl'} -- people.there
# {'people', 'peopl'} -- people.also
# {'people', 'peopl'} -- people  the
# {'people', 'peopl'} -- people.these
# {'people', 'peopl'} -- people  even
# {'people', 'peopl'} -- people.for
# {'people', 'peopl'} -- peoplet
# {'people', 'peopl'} -- people  but
# {'people', 'peopl'} -- peoply
# {'people', 'peopl'} -- people  especially
# {'people', 'peopl'} -- peoplle
# {'people', 'peopl'} -- peopls
# {'people', 'peopl'} -- people  not
# {'people', 'peopl'} -- people.yes
# {'white'} -- white
# {'white'} -- white.the
# {'white'} -- white looking
# {'white'} -- non white
# {'white'} -- white white
# {'white'} -- white.this
# {'white'} -- white.
# {'white'} -- whites
# {'white'} -- white.a
# {'white'} -- white.it
# {'white'} -- white ish
# {'white'} -- white.so
# {'white'} --  white
# {'white'} -- .white
# {'white'} -- not white
# {'white'} -- white.and
# {'white'} -- white.in
# {'white'} -- white.you
# {'white'} -- white.but
# {'white'} -- all white
# {'white'} -- mostly white
# {'white'} -- ultra white
# {'white'} -- white gray
# {'white'} -- andwhite
# {'white'} -- off white
# {'white'} -- near white
# {'white'} -- white
# {'white'} -- white grey
# {'white'} -- white based
# {'white'} -- nonwhite
# {'white'} -- white black
# {'white'} -- almost white
# {'white'} -- white colored
# {'white'} -- white.if
# {'white'} -- white.i
# {'white'} -- ofwhite
# {'white'} -- pure white
# {'white'} -- white.there
# {'white'} -- super white
# {'white'} -- white.we
# {'white'} -- white.what
# {'white'} -- thewhite
# {'white'} -- snow white
# {'white'} -- .white
# {'white'} -- whiteness
# {'white'} -- white striped
# {'white'} -- white coloured
# {'terror'} -- terrorism
# {'terror'} -- terrorist
# {'terror'} -- terror
# {'terror'} -- terror.the
# {'terror'} -- terror.i
# {'terror'} -- terror.
# {'terror'} -- terror
# {'terror'} -- terror.in
# {'terror'} -- terrorists
# {'terror'} -- terrorisms
# {'terror'} -- terrorism.the
# {'terror'} -- terrori
# {'terror'} -- terrors
# {'terror'} -- terrorism
# {'terror'} -- terroris
# {'terror'} -- terrorism
# {'terror'} -- terrorism.it
# {'terror'} -- terrorism.but
# {'terror'} -- terrorism.this
# {'terror'} -- terrorism.in
# {'terror'} -- terrorist
# {'terror'} -- terrorism.i
# {'terror'} -- terrorists.the
# {'terror'} -- terror bombing
# {'terror'} -- counter terror
# {'terror'} -- terrorism.
# {'terror'} -- terrorist like
# {'terror'} -- terrorismthe
# {'terror'} -- cyber terror
# {'terror'} -- terror filled
# {'terror'} -- terrorists.it
# {'terror'} -- terror related
# {'terror'} -- terroristic
# {'terror'} -- 'terror
# {'terror'} -- narcoterrorism
# {'terror'} -- terrorist related
# {'terror'} -- cyberterror
# {'terror'} -- terrorist.the
# {'terror'} -- terrorists
# {'terror'} -- terrorthe
# {'terror'} -- counterterror
# {'terror'} -- terror inducing
# {'terror'} -- terrorisation
# {'terror'} -- terrorisme
# {'sexist'} -- sexists
# {'sexist'} -- heterosexist
# {'sexist'} -- sexist
# {'sexist'} -- sexist.
# {'sexist'} -- cissexist
# {'sexist'} -- sexist
# {'sexist'} -- non sexist
# {'sexist'} -- anti sexist
# {'classy', 'classi'} -- classy
# {'classy', 'classi'} -- classier
# {'classy', 'classi'} -- classy.
# {'classy', 'classi'} -- classy looking
# {'classy', 'classi'} -- classy.i
# {'classy', 'classi'} -- classiest
# {'classy', 'classi'} -- unclassy
# {'classy', 'classi'} -- classiness
# {'classy', 'classi'} -- classic looking
# {'classy', 'classi'} -- classy
# {'sassy', 'sassi'} -- sassiest
# {'sassy', 'sassi'} -- sassiness
# {'sassy', 'sassi'} -- sassier
# {'sassy', 'sassi'} -- sassy
# {'sassy', 'sassi'} -- sassily
# {'nasty', 'nasti'} -- nastier
# {'nasty', 'nasti'} -- nastiest
# {'nasty', 'nasti'} -- nasty looking
# {'nasty', 'nasti'} -- nasty
# {'nasty', 'nasti'} -- nastiness
# {'nasty', 'nasti'} -- nastily
# {'nasty', 'nasti'} -- nasty ass
# {'nasty', 'nasti'} -- nasty
# {'nasty', 'nasti'} -- nasty.i
# {'nasty', 'nasti'} -- nasty.
# {'nasty', 'nasti'} -- nastyness
# {'nasty', 'nasti'} -- nasties
# {'stupid'} -- stupid
# {'stupid'} -- stupid.and
# {'stupid'} -- stupid
# {'stupid'} -- stupid.so
# {'stupid'} -- stupid.but
# {'stupid'} -- stupid.
# {'stupid'} -- stupid ass
# {'stupid'} -- stupid.what
# {'stupid'} -- stupidly
# {'stupid'} -- stupids
# {'stupid'} -- stupidass
# {'stupid'} -- stupid.it
# {'stupid'} -- stupidest
# {'stupid'} -- stupider
# {'stupid'} -- stupid.this
# {'stupid'} -- stupid
# {'stupid'} -- stupid.if
# {'stupid'} -- non stupid
# {'stupid'} -- stupid.you
# {'stupid'} -- .stupid
# {'stupid'} -- stupid.they
# {'shit'} -- shit.and
# {'shit'} -- shits
# {'shit'} -- shit.that
# {'shit'} -- shitt
# {'shit'} -- shit.what
# {'shit'} -- shit.
# {'shit'} -- shit
# {'shit'} -- shite
# {'shit'} -- shit.i
# {'shit'} -- bullshit
# {'shit'} -- shit.so
# {'shit'} -- shit.but
# {'shit'} -- shit.it
# {'shit'} -- shit.you
# {'shit'} -- shit
# {'shit'} -- shit.if
# {'shit'} -- shit
# {'shit'} -- shit.he
# {'shit'} -- shit.this
# {'shit'} -- shit.the
# {'shit'} -- shit.we
# {'shit'} -- shitballs
# {'shit'} -- shitty
# {'shit'} -- dogshit
# {'shit'} -- horseshit
# {'shit'} -- shit.i
# {'shit'} -- shitted
# {'shit'} -- shithead
# {'shit'} -- horse shit
# {'shit'} -- shitload
# {'shit'} -- shitting
# {'shit'} -- dipshit
# {'shit'} -- shitheads
# {'idiot'} -- idiots
# {'idiot'} -- idiot
# {'idiot'} -- idiot.i
# {'idiot'} -- idiot.
# {'idiot'} -- idiot.and
# {'idiot'} -- idiotic
# {'idiot'} -- idiot.if
# {'idiot'} -- idiot.you
# {'idiot'} -- idiot.the
# {'idiot'} -- idiot.it
# {'trump'} -- trumps
# {'trump'} -- trumping
# {'trump'} -- trumph
# {'trump'} -- trump.
# {'trump'} -- trumps
# {'trump'} -- trumped
# {'trump'} -- anti trump
# {'trump'} -- trumps
# {'trump'} -- trump
# {'trump'} -- no trump
# {'trump'} -- trumping
# {'trump'} -- nevertrump
# {'trump'} -- donaldtrump
# {'trump'} -- trump
# {'trump'} -- trump.
# {'trump'} -- trump
# {'trump'} -- mr.trump
# {'trump'} -- trump style
# {'trump'} -- trump.the
# {'trump'} -- pmtrump
# {'trump'} -- it.trump
# {'trump'} -- trump.but
# {'trump'} -- trumpo
# {'trump'} -- trumpus
# {'trump'} -- trumpkins
# {'trump'} -- amtrump
# {'trump'} -- trump
# {'nigga'} -- niggas
# {'nigga'} -- niggaz
# {'nigga'} -- nigga
# {'nigga'} -- niggah
# {'nigga'} -- nigga.
# {'nigga'} -- niggai
# {'nigga'} -- niggas
# {'nigga'} -- niggahs
# {'nigga'} -- niggaz
# {'nigga'} -- niggayou
# {'giveaway'} -- giveaway
# {'giveaway'} -- giveaway
# {'giveaway'} -- giveaway
# {'giveaway'} -- giveaway.i
# {'giveaway'} -- giveaways
# {'giveaway'} -- giveaway.the
# {'giveaway'} -- giveaway.
# {'giveaway'} -- giveaways.
# {'giveaway'} -- giveawayi
# {'giveaway'} -- giveaway
# {'giveaway'} -- giveaway.thanks
# {'giveaway'} -- giveaway
# {'giveaway'} -- giveaways
# {'giveaway'} -- giveaway.my
# {'giveaway'} -- giveaways
# {'giveaway'} -- giveaways
# {'giveaway'} -- giveawaythe
# {'giveaway'} -- giveawayhttp
# {'giveaway'} -- giveaway.http
# {'giveaway'} -- non giveaway
# {'giveaway'} -- bookgiveaway
# {'enter'} -- entering
# {'enter'} -- entered
# {'enter'} -- re enter
# {'enter'} -- enter
# {'enter'} -- enter.the
# {'enter'} -- reenter
# {'enter'} -- entering
# {'enter'} -- enters
# {'enter'} -- entere
# {'enter'} -- enterthe
# {'enter'} -- enter.you
# {'enter'} -- enter.i
# {'enter'} -- enter.this
# {'enter'} -- toenter
# {'enter'} -- enter.
# {'enter'} -- enteres
# {'enter'} --  enter
# {'enter'} -- enterd
# {'enter'} -- re entering
# {'enter'} -- enterring
# {'enter'} -- enter
# {'enter'} -- enterting
# {'enter'} -- enter
# {'enter'} -- pre enter
# {'enter'} -- entered.
# {'enter'} -- reenter
# {'enter'} --  enter
# {'enter'} -- re entered
# {'enter'} -- reentering
# {'enter'} -- enterred
# {'enter'} -- entered.the
# {'enter'} -- 3enter
# {'enter'} -- reentered
# {'enter'} -- entery
# {'enter'} -- entering.
# {'enter'} -- enterin
# {'enter'} -- enter
# {'enter'} -- entered.i
# {'enter'} -- re enters
# {'enter'} -- entering
# {'enter'} -- entera
# {'enter'} -- re enter
# {'enter'} -- enter to win
# {'enter'} -- re entering
# {'enter'} -- entered
# {'enter'} -- reenters
# {'guy'} -- guy.he
# {'guy'} -- guy  he
# {'guy'} -- guy.a
# {'guy'} -- guy.
# {'guy'} -- guy
# {'guy'} -- guy
# {'guy'} -- guy.now
# {'guy'} -- guys
# {'guy'} -- guy.that
# {'guy'} -- guy.but
# {'guy'} -- guy.the
# {'guy'} -- guy.i
# {'guy'} -- guy.so
# {'guy'} -- guy.this
# {'guy'} -- guy.what
# {'guy'} -- guy.you
# {'guy'} -- guy.and
# {'guy'} -- guy.if
# {'guy'} -- guy.when
# {'guy'} -- guy.it
# {'guy'} -- guy.as
# {'guy'} -- guy.my
# {'guy'} -- guy.in
# {'guy'} -- guy.well
# {'guy'} -- guy.there
# {'guy'} -- guy.here
# {'guy'} -- guy.we
# {'guy'} --  guy
# {'guy'} -- guyfriend
# {'good'} -- good
# {'good'} -- semi good
# {'good'} -- good.good
# {'good'} -- not so good
# {'good'} -- good ish
# {'good'} -- tgood
# {'good'} -- good
# {'good'} -- good.great
# {'good'} -- less than good
# {'good'} -- agood
# {'good'} -- good  a
# {'good'} -- super good
# {'good'} -- too.good
# {'good'} -- better.good
# {'good'} -- good.nice
# {'good'} -- nice.good
# {'good'} -- great.good
# {'good'} -- good.this
# {'good'} -- not good
# {'good'} --  good
# {'good'} -- good.a
# {'good'} -- well.good
# {'good'} -- right.good
# {'good'} -- time.good
# {'good'} -- much.good
# {'good'} -- fun.good
# {'good'} -- thing.good
# {'good'} -- .good
# {'good'} -- good.well
# {'good'} -- good.not
# {'good'} -- good
# {'good'} -- good.the
# {'good'} -- .good
# {'good'} -- good.just
# {'good'} -- good good
# {'good'} -- v.good
# {'good'} -- good.another
# {'good'} -- good.for
# {'good'} -- good.that
# {'good'} -- money.good
# {'good'} -- sure.good
# {'good'} -- good enough
# {'good'} -- enough.good
# {'good'} -- best.good
# {'good'} -- see.good
# {'gone'} -- gone.so
# {'gone'} -- gone.i
# {'gone'} -- gone.well
# {'gone'} -- gone
# {'gone'} -- gone
# {'gone'} -- gone.and
# {'gone'} -- gone.now
# {'gone'} -- gone.but
# {'gone'} -- gone.they
# {'gone'} -- gone.we
# {'gone'} -- gone.it
# {'gone'} -- gone
# {'gone'} -- gone.then
# {'gone'} -- gone.as
# {'gone'} -- gone.what
# {'gone'} -- gone.she
# {'gone'} -- gone.when
# {'gone'} -- gone.that
# {'gone'} -- gone.
# {'gone'} -- gone.he
# {'gone'} -- gone.this
# {'gone'} -- gone.the
# {'gone'} -- gone.if
# {'gone'} -- gone.no
# {'fuck'} -- fucking
# {'fuck'} -- fucks
# {'fuck'} -- fucked
# {'fuck'} -- fuck
# {'fuck'} -- fucker
# {'fuck'} -- fuckin
# {'fuck'} -- fucko
# {'fuck'} -- fuck.
# {'fuck'} -- fuckers
# {'fuck'} -- fuck.i
# {'fuck'} -- fuck.
# {'fuck'} -- fucki
# {'fuck'} -- fucksake
# {'fuck'} -- fuckk
# {'fuck'} -- fucken
# {'fuck'} -- fuck
# {'fuck'} -- fucki
# {'fuck'} -- skullfuck
# {'fuck'} -- .fuck
# {'fuck'} -- fuckface
# {'fuck'} -- youfuck
# {'fuck'} -- fuck
# {'fuck'} -- mother fucker
# {'fuck'} -- buttfuck
# {'fuck'} -- fuckt
# {'fuck'} -- fucke
# {'fuck'} -- fucking
# {'fuck'} -- fuckn
# {'fuck'} -- mother fuckers
# {'fuck'} -- fuckity
# {'fuck'} -- fucks.
# {'fuck'} -- fuckhead
# {'fuck'} -- motherfuck
# {'fuck'} -- butt fuck
# {'fuck'} -- finger fuck
# {'fuck'} -- fuckstick
# {'fuck'} -- fuckign
# {'fuck'} -- fucked.
# {'fuck'} -- face fuck
# {'fuck'} -- fuckheads
# {'fuck'} -- fucksticks
# {'fuck'} -- fucket
# {'fuck'} -- tofuck
# {'fuck'} -- fucky
# {'fuck'} -- fuckfaces
# {'fuck'} -- butt fucked
# {'fuck'} -- fucktard
# {'little', 'littl'} -- littly
# {'little', 'littl'} -- llittle
# {'little', 'littl'} -- alittle
# {'little', 'littl'} -- littlle
# {'little', 'littl'} -- littler
# {'little', 'littl'} -- littl
# {'little', 'littl'} -- little bit
# {'little', 'littl'} -- little.a
# {'little', 'littl'} -- not so little
# {'little', 'littl'} -- little.the
# {'little', 'littl'} -- littlest
# {'little', 'littl'} -- littled
# {'little', 'littl'} -- little.as
# {'little', 'littl'} -- little.this
# {'little', 'littl'} -- littlt
# {'as', 'ass'} -- asses
# {'as', 'ass'} -- ass.i
# {'as', 'ass'} -- ass.
# {'as', 'ass'} -- ass.but
# {'as', 'ass'} -- ass.and
# {'as', 'ass'} -- ass.that
# {'as', 'ass'} -- asss
# {'as', 'ass'} -- ass.this
# {'as', 'ass'} -- ass.if
# {'as', 'ass'} -- ass.you
# {'as', 'ass'} -- ass.the
# {'as', 'ass'} -- ass
# {'as', 'ass'} -- ass.he
# {'as', 'ass'} -- asshole
# {'as', 'ass'} -- assss
# {'as', 'ass'} -- ass.in
# {'as', 'ass'} -- ass.so
# {'as', 'ass'} -- ass.it
# {'as', 'ass'} -- ass.we
# {'as', 'ass'} -- ass.what
# {'as', 'ass'} -- ass.she
# {'as', 'ass'} -- assed
# {'as', 'ass'} -- ass hole
# {'as', 'ass'} -- asses.
# {'as', 'ass'} -- assery
# {'as', 'ass'} -- ass
# {'as', 'ass'} -- asspussy
# {'as', 'ass'} -- assness
# {'as', 'ass'} -- pussy ass
# {'as', 'ass'} -- asscheeks
# {'as', 'ass'} -- ass
# {'as', 'ass'} -- asscheek
# {'bitch'} -- bitches
# {'bitch'} -- bitch ass
# {'bitch'} -- bitche
# {'bitch'} -- bitch.
# {'bitch'} -- bitch.the
# {'bitch'} -- bitchy
# {'bitch'} -- bitch
# {'bitch'} -- bitch
# {'bitch'} -- bitchs
# {'bitch'} -- bitch.i
# {'bitch'} -- bitch
# {'bitch'} -- mega bitch
# {'bitch'} -- bitchass
# {'bitch'} -- bitched
# {'bitch'} -- bitching
# {'bitch'} -- sonofabitch
# {'die'} -- dies
# {'die'} -- die
# {'die'} -- die
# {'die'} -- die.
# {'die'} -- die.this
# {'die'} -- die.but
# {'die'} -- dieing
# {'die'} -- die.so
# {'die'} -- die.the
# {'die'} -- die.and
# {'die'} -- die.as
# {'die'} -- die.now
# {'die'} -- die.that
# {'die'} -- die.a
# {'die'} -- die.if
# {'die'} -- die.for
# {'die'} -- die.what
# {'die'} -- die.we
# {'die'} -- dieing
# {'die'} -- die.it
# {'die'} -- die
# {'die'} -- die
# {'die'} -- die.when
# {'die'} -- die.he
# {'die'} -- die.i
# {'die'} -- died
# {'die'} -- die.in
# {'die'} -- die.you
# {'die'} -- die.my
# {'die'} -- dies.i
# {'die'} -- die.2.
# {'die'} -- die.there
# {'die'} -- dies.the
# {'die'} -- diein
# {'die'} -- die.she
# {'die'} -- dies
# {'die'} -- dies.
# {'die'} -- diea
# {'die'} -- die.
# {'die'} -- dieand
# {'die'} -- diei
# {'die'} -- die
# {'die'} -- todie
# {'die'} -- dieand
# {'die'} -- die.they
# {'die'} -- die1
# {'die'} -- dies
# {'die'} -- dies
# {'die'} -- diethe

# %%
displayDF(word_clusters)
#word_clusters
# Out:
#          people          white             terror         sexist  \
# 0         peope          black              terro   misogynistic
# 1        poeple          whtie           atrocity     misogynist
# 2         peole           blue         terrrorist   mysogynistic
# 3        peopel          balck           jihadist   mysoginistic
# 4         folks            red             jihadi   chauvinistic
# 5         those         yellow           terroism     mysoginist
# 6   individuals           grey              teror     mysogynist
# 7       poeople           gray           terroist  anti-feminist
# 8       peoople          brown    suicide-bombing    anti-female
# 9       peopole        colored          extremism     misandrist
# 10        peple         purple            carnage      misandric
# 11      peolple          beige              jihad  gender-biased
# 12       peolpe           pink      ISIS-inspired      misogynic
# 13          ppl      non-black      Islamofascist     anti-woman
# 14       others          blakc  Islamist-inspired      anti-male
# 15       prople      black-and      frightfulness         sexism
# 16      persons     black-and-  al-Qaeda-inspired     misogynous
# 17      peoeple         blacks           jihadism    un-feminist
# 18        pople           whte           terorist     unfeminist
# 19     citizens         -black      state-sponsor  anti-feminine
# 20       pepole  light-colored          jihadists   woman-hating
# 21          who     light-blue           Islamist     chauvinist
# 22      pepople         maroon           bombings   male-bashing
# 23    Americans        grayish             jehadi     anti-women
# 24         many  cream-colored           terorism       anti-men
# 25      peopple  black-colored            bombing         racist
# 26  indivuduals    non-colored             attack       anti-man
# 27       epople      black.And           al-Qaeda   chauvanistic
# 28      peopele      black.The          barbarity   antifeminist
# 29       peopke    black-black       suicide-bomb       misogyny
#
#              classy          sassy          nasty       stupid      shit  \
# 0           stylish         spunky           icky         dumb      crap
# 1           elegant         feisty     unpleasant      idiotic      sh1t
# 2              chic  smart-mouthed           vile      moronic     shyte
# 3          tasteful          saucy         horrid        silly   goddamn
# 4            sylish         fiesty          yucky      asinine      shiz
# 5             sleek           sass         narsty      dumbass      shyt
# 6           elegent         flirty           ugly      stoopid      sh-t
# 7            chique          witty       horrible     dumb-ass   fucking
# 8            trendy           sexy     disgusting    stoooopid    fuckin
# 9        glamourous      vivacious        vicious        idiot      fuck
# 10        glamorous     whip-smart    not-so-nice   ridiculous     shiit
# 11            sleak         mouthy       spiteful      foolish      shxt
# 12    sophisticated      spit-fire         filthy     ignorant     shiet
# 13             edgy         snarky          dirty        moron      s---
# 14      fashionable          kicky         gnarly        supid    fucken
# 15      elegant.The         bitchy            bad     stooopid     shizz
# 16     uber-stylish          ditzy           nasy   dumb-assed      sh.t
# 17         stylish-         cheeky          awful        stupd    schitt
# 18        lady-like  sharp-tongued       viscious   stooooopid      piss
# 19           demure           edgy  mean-spirited     retarded      damn
# 20             sexy   quick-witted      unplesant   fucktarded     shiat
# 21         ladylike    smart-mouth          slimy      stuipid   shiiiit
# 22       high-class         demure     hellacious     assinine   shiznit
# 23            suave    flirtatious     unpleasent    dumbassed     bitch
# 24         elegant-          bossy         smelly      stupied      sh--
# 25    ultra-stylish           foxy         snotty       idiots      shlt
# 26     rich-looking         sultry        hateful   rediculous       sht
# 27         un-fussy  wise-cracking       terrible    dumbasses    godamn
# 28  elegant-looking         quippy          wasty       morons  god-damn
# 29     good-looking     fun-loving         stinky  idiotically  godamned
#
#          idiot      trump         nigga      giveaway         enter  \
# 0        moron     drumpf    muthafucka       giveway        eneter
# 1      dumbass     donald    mothafucka     give-away      enetered
# 2     imbecile     ivanka         n-gga    give-a-way     enetering
# 3         dolt    hillary   muthafuckas       givaway       exiting
# 4      dipshit     bannon        nigguh     givewaway          exit
# 5       dimwit      obama         tryna    Give-a-way        exited
# 6       nitwit    melania         niqqa      giveways  RaffleCopter
# 7    numbskull    ruffing        n-ggas     Give-away   participate
# 8     fucktard   clintons          bruh       giveawy       proceed
# 9      jackass     spades   mothafuckas       Giveway         leave
# 10      doofus    clinton        shawty      givaways        sumbit
# 11      asshat     obamas         homie     Give-Away        submit
# 12   ignoramus     farage           gon     GIVE-AWAY        select
# 13  nincompoop      putin   muthafuckin       Givaway       receive
# 14    dumbshit  supercede         finna    give-aways      activate
# 15      morons     putins   mothafuckin   give-a-ways          join
# 16   douchebag    gorsuch   muthafucker  rafflecopter         entry
# 17       idjit   off-suit        niccas     Blogmania     entry.You
# 18    dickhead      potus        trynna     tour-wide      entrants
# 19     fuckwit     Drumpf         nicca    Give-aways       entring
# 20    dumb-ass  doubleton          shyt  Rafflecopter          into
# 21    assclown     PEOTUS       thuggin    Give-Aways        choose
# 22    shithead   Shillary         n---a      prizes.I        key-in
# 23     asswipe        usa       stuntin      blogtour         exits
# 24        idot  breitbart       frontin    SewMamaSew        checko
# 25    dumbfuck   hillarys          fucc    Give-A-Way      receivee
# 26      cretin    hitlery   motherfucka    Entry-Form         begin
# 27       idoit  over-rule  muthafucking   sweepstakes      tainment
# 28  ignoramous     jokers         sucka     blogcandy  rafflecopter
# 29     halfwit    killary         jigga       BlogHop       entrant
#
#             guy          good          gone         fuck      little  \
# 0          dude           bad   disappeared          fuk         bit
# 1         fella         great      vanished         shit     litttle
# 2           man        decent          went        bitch      liitle
# 3         bloke          nice          been         dick       litle
# 4         dudes     excellent  dissappeared        fuuck      teensy
# 5   knucklehead         goood        gotten         fuxk         wee
# 6       schmuck          ggod   dissapeared         fukc     lilttle
# 7     douchebag      terrific     forgotten      asshole       teeny
# 8      somebody         lousy          come         piss         tad
# 9         d-bag        better          done        phuck         lil
# 10       doofus          very    disapeared      jackoff      litlte
# 11      someone     fantastic         kaput       bitchs        tiny
# 12       a-hole          geat         going        cunts       lttle
# 13       shmuck         so-so    reappeared         wank      litlle
# 14       schlub        pretty          goes         cunt      smidge
# 15        buddy          best         never       fuuuck     liittle
# 16          kid        really           had      bitches    leeeetle
# 17         chap      terrible           got         slut  liiiiittle
# 18        dweeb   super-great        turned      fukcing     teeeeny
# 19    gentleman          darn   re-appeared        pussy     leeetle
# 20      dumbass      excelent    disappeard   cocksucker   liiiittle
# 21       hottie     wonderful          came    pussy-ass       bitty
# 22         bozo        baaaad       changed        fucck    liiiitle
# 23     goofball        superb    disppeared        horny      teeeny
# 24     dickhead  not-so-great          awol         suck      teency
# 25   though--he       perfect         beeen      fuuuuck      ltitle
# 26       man.He        gooood    disappered        dicks    liiittle
# 27       A-hole          damn       already         fack       eensy
# 28     meathead         GREAT       forever  cocksuckers   teensiest
# 29       fellar   suprisingly          hadn         fcuk     smidgen
#
#               ass          bitch           die
# 0            arse         biatch         dying
# 1            butt         biotch        perish
# 2             azz         beotch        wither
# 3            dick         fucker         hards
# 4          butt.I        beyotch          kill
# 5          fucker        asshole  twenty-sided
# 6           hiney       beeyotch        starve
# 7           arse.        beyatch       shrivel
# 8           butt.       beeyatch         death
# 9           bitch        beeotch        sicken
# 10          pussy       shithead          dead
# 11        titties       fucktard        suffer
# 12        keister          whore       Accucut
# 13           cunt           slut       survive
# 14          arses           fuck      sizzlits
# 15          butts          skank       sizzlit
# 16           tits          bytch       sizzlet
# 17           arss           shit      striplet
# 18         tuckus        dickwad        killed
# 19        nutsack       dickhead      perished
# 20           bumm        fucking  spellbinders
# 21          butt-        bastard      thinlets
# 22            bum          b---h   prematurely
# 23           shit  mother-fucker     bloodloss
# 24  you-know-what       biznatch        doomed
# 25           twat            ass        Sissix
# 26        fucking         Biotch     perishing
# 27       butthole       fuckhead      20-sided
# 28         arse.I          b----          XCut
# 29        patooty          pissy       Sizzlit

# %%
plotTSNE("Similar words - fastText [t-SNE]", word_clusters, embedding_clusters, "SimilarWords - fastText - t-SNE.png")
# Out:
# (22, 30, 300)

# %%
plotMDS("Similar words - fastText [MDS]", word_clusters, embedding_clusters, "SimilarWords - fastText - MDS.png")

# %%
plotPCA("Similar words - fastText [PCA]", word_clusters, embedding_clusters, "SimilarWords - fastText - PCA.png")

# %% [markdown]
# ## Clustering

# %%
avg_embeddings = dict()
for i, key in enumerate(FIXED_KEYS):
    avg_embeddings[key]= np.mean(np.array(embedding_clusters[i]), axis = 0)

# %% [markdown]
# ### Kmeans

# %%
dist_matrix = 1 - cosine_similarity(list(avg_embeddings.values()))
range_clusters = list(range(2,16))
for num_clusters in range_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(dist_matrix)
    clusters = km.labels_.tolist()
    silhouette_avg = silhouette_score(dist_matrix, clusters)
    print(f"{num_clusters} clusters - silhouette: {silhouette_avg}")

# %%
num_clusters = 9
km = KMeans(n_clusters=num_clusters)

# Perform clustering
# %time km.fit(dist_matrix)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))

# %%
for i in range(num_clusters):
    print(f"Cluster {i}: {np.array(FIXED_KEYS)[np.where(i == np.array(clusters))[0]]}")

# %%
### Hierarchical clustering

# %%
from scipy.cluster.hierarchy import ward, dendrogram
# %matplotlib inline

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_matrix) 

fig, ax = plt.subplots(figsize=(5, 6)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=FIXED_KEYS);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()
